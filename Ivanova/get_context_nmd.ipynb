# %% [markdown]
# ### Содержание
#
# 1. [Подготовка датафреймов](#Подготовка-датафреймов)
#    1.1 [Фильтруем общий датафрейм](#Фильтруем-общий-датафрейм)
#    1.2 [Добавляем метрику LOEUF](#Добавляем-метрику-LOEUF)
#    1.3 [Добавляем метрику pext](#Добавляем-метрику-pext)
#    1.4 [Получение NMD(-) регионов](#Получение-NMD(-)-регионов)
#    1.5 [Добавление статуса NMD в датафрейм](#Добавление-статуса-NMD-в-датафрейм)
# 3. [Разделение на NMD(+) и NMD(-) датафреймы](#Разделение-на-NMD(+)-и-NMD(-)-датафреймы)
# 4. [Разделение вариантов по значению патогенности](#Разделение-вариантов-по-значению-патогенности)
#    3.1 [Разделение по AC](#Разделение-по-AC)
#    3.2 [Обработка датафрейма Clinvar](#Обработка-датафрейма-Clinvar)
#    3.3 [Убираем из условно доброкачественных вариантов все паты по Clinvar](#Убираем-из-условно-доброкачественных-вариантов-все-паты-Clinvar)
#    3.4 [Добавляем в условно патогенные варианты все непопуляционные паты Clinvar](#Добавляем-в-условно-патогенные-варианты-все-непопуляционные-паты-Clinvar)
# 5. [Сбалансируем датафреймы](#Сбалансируем-датафреймы)
# 6. [Посмотрим на распределение кДНК позиций относительно начала и конца транскриптов](#Посмотрим-на-распределение-кДНК-позиций-относительно-начала-и-конца-транскриптов)
# 7. [Получение контекста последовательности](#Получение-контекста-последовательности)
# 8. [Проверим, точно ли всё правильно сделали при обработке датафреймов](#Проверим,-точно-ли-всё-правильно-сделали-при-обработке-датафреймов)
# 9. [Построение лого с помощью logomaker](#Построение-лого-с-помощью-logomaker)
# 10. [Статистическое сравнение позиций в контекстах](#Статистическое-сравнение-позиций-в-контекстах)

# %%
import datetime
import json
import logomaker as lm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pyliftover
import seaborn as sns
import seqlogo

from pyfaidx import Fasta
from scipy.stats import chi2_contingency
from os.path import join

# %% [markdown]
# **В этом ноутбуке представлены результаты для вариантов, которые <font color="red"> подвергаются </font> NMD.**

# %% [markdown]
# ### Подготовка датафреймов

# %% [markdown]
# Преобразуем имеющиеся таблицы tsv в датафреймы и объединяем всё в один датафрейм.

# %%
DATA_PATH = "data_dir/canonical_ensemble"

# %%
chromosomes = ['chr' + str(i) for i in range(1, 23)]  # только аутосомы
frames = [pd.read_table(join(DATA_PATH, f"gnomad.exomes.v4.0.sites.{chromosome}.vcf.tsv")) for chromosome in chromosomes]

all_chrom_df = pd.concat(frames)
# Out:
# /tmp/ipykernel_3118914/2292932966.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   frames = [pd.read_table(join(DATA_PATH, f"gnomad.exomes.v4.0.sites.{chromosome}.vcf.tsv")) for chromosome in chromosomes]
# /tmp/ipykernel_3118914/2292932966.py:2: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   frames = [pd.read_table(join(DATA_PATH, f"gnomad.exomes.v4.0.sites.{chromosome}.vcf.tsv")) for chromosome in chromosomes]
# /tmp/ipykernel_3118914/2292932966.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   frames = [pd.read_table(join(DATA_PATH, f"gnomad.exomes.v4.0.sites.{chromosome}.vcf.tsv")) for chromosome in chromosomes]
# /tmp/ipykernel_3118914/2292932966.py:2: DtypeWarning: Columns (10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   frames = [pd.read_table(join(DATA_PATH, f"gnomad.exomes.v4.0.sites.{chromosome}.vcf.tsv")) for chromosome in chromosomes]

# %%
all_chrom_df.shape
# Out:
# (67528142, 14)

# %%
all_chrom_df.dtypes
# Out:
# Chr                     object
# Position                 int64
# rsID                    object
# Ref                     object
# Alt                     object
# Impact                  object
# Consequence             object
# Gene_symbol             object
# Canonical_transcript    object
# cDNA_position           object
# LoF                     object
# LoF_flag                object
# LoF_filter              object
# AC                       int64
# dtype: object

# %%
all_chrom_df = all_chrom_df.rename(columns={'Chr': 'CHROM', 'Position': 'POS', 'Ref': 'REF', 'Alt': 'ALT'})

# %%
all_chrom_df
# Out:
#          CHROM       POS          rsID  REF ALT                        Impact  \
# 0         chr1     12541             .    C   G  MODIFIER, MODIFIER, MODIFIER
# 1         chr1     12591  rs1553119381    C   T  MODIFIER, MODIFIER, MODIFIER
# 2         chr1     12592             .    C   T  MODIFIER, MODIFIER, MODIFIER
# 3         chr1     12599  rs1437963543   CT   C       LOW, MODIFIER, MODIFIER
# 4         chr1     12612  rs1205998786  GGT   G       LOW, MODIFIER, MODIFIER
# ...        ...       ...           ...  ...  ..                           ...
# 1621633  chr22  50799702     rs4081531    G   A                      MODIFIER
# 1621634  chr22  50799821   rs149733995    A   C                      MODIFIER
# 1621635  chr22  50801218   rs368061391    G   A                      MODIFIER
# 1621636  chr22  50801236   rs113976139    C   G                      MODIFIER
# 1621637  chr22  50801268   rs370064763    T   C                      MODIFIER
#
#                                                Consequence  \
# 0        intron_variant&non_coding_transcript_variant, ...
# 1        intron_variant&non_coding_transcript_variant, ...
# 2        intron_variant&non_coding_transcript_variant, ...
# 3        splice_polypyrimidine_tract_variant&intron_var...
# 4        splice_region_variant&non_coding_transcript_ex...
# ...                                                    ...
# 1621633                            downstream_gene_variant
# 1621634                            downstream_gene_variant
# 1621635                            downstream_gene_variant
# 1621636                            downstream_gene_variant
# 1621637                            downstream_gene_variant
#
#                         Gene_symbol  \
# 0        DDX11L1, WASH7P, MIR6859-1
# 1        DDX11L1, WASH7P, MIR6859-1
# 2        DDX11L1, WASH7P, MIR6859-1
# 3        DDX11L1, WASH7P, MIR6859-1
# 4        DDX11L1, WASH7P, MIR6859-1
# ...                             ...
# 1621633                   RPL23AP82
# 1621634                   RPL23AP82
# 1621635                   RPL23AP82
# 1621636                   RPL23AP82
# 1621637                   RPL23AP82
#
#                                       Canonical_transcript cDNA_position  LoF  \
# 0        ENST00000450305, ENST00000488147, ENST00000619216           NaN  NaN
# 1        ENST00000450305, ENST00000488147, ENST00000619216           NaN  NaN
# 2        ENST00000450305, ENST00000488147, ENST00000619216           NaN  NaN
# 3        ENST00000450305, ENST00000488147, ENST00000619216           NaN  NaN
# 4        ENST00000450305, ENST00000488147, ENST00000619216         98-99  NaN
# ...                                                    ...           ...  ...
# 1621633                                    ENST00000427528           NaN  NaN
# 1621634                                    ENST00000427528           NaN  NaN
# 1621635                                    ENST00000427528           NaN  NaN
# 1621636                                    ENST00000427528           NaN  NaN
# 1621637                                    ENST00000427528           NaN  NaN
#
#         LoF_flag LoF_filter   AC
# 0            NaN        NaN    1
# 1            NaN        NaN    5
# 2            NaN        NaN    5
# 3            NaN        NaN   14
# 4            NaN        NaN    1
# ...          ...        ...  ...
# 1621633      NaN        NaN  377
# 1621634      NaN        NaN   11
# 1621635      NaN        NaN    1
# 1621636      NaN        NaN   18
# 1621637      NaN        NaN    1
#
# [67528142 rows x 14 columns]

# %% [markdown]
# #### Фильтруем общий датафрейм

# %% [markdown]
# Оставляем только однонуклеотидные стопгейны.

# %%
lof_final_df = all_chrom_df[all_chrom_df['Consequence'] == 'stop_gained']
lof_final_df
# Out:
#          CHROM       POS          rsID REF ALT Impact  Consequence  \
# 199       chr1     69548  rs1211934440   T   A   HIGH  stop_gained
# 4666      chr1    925933  rs1409697303   A   T   HIGH  stop_gained
# 4692      chr1    925960             .   C   T   HIGH  stop_gained
# 4728      chr1    925996             .   C   T   HIGH  stop_gained
# 5071      chr1    930221   rs934852613   C   T   HIGH  stop_gained
# ...        ...       ...           ...  ..  ..    ...          ...
# 1619819  chr22  50769106   rs559977293   G   A   HIGH  stop_gained
# 1620148  chr22  50769969             .   C   T   HIGH  stop_gained
# 1620665  chr22  50775796  rs1555923164   G   T   HIGH  stop_gained
# 1620705  chr22  50775845             .   C   T   HIGH  stop_gained
# 1620875  chr22  50776725   rs375595282   G   T   HIGH  stop_gained
#
#         Gene_symbol Canonical_transcript cDNA_position LoF LoF_flag  \
# 199           OR4F5      ENST00000641515           581  HC      NaN
# 4666         SAMD11      ENST00000616016          1038  HC      NaN
# 4692         SAMD11      ENST00000616016          1065  HC      NaN
# 4728         SAMD11      ENST00000616016          1101  HC      NaN
# 5071         SAMD11      ENST00000616016          1185  HC      NaN
# ...             ...                  ...           ...  ..      ...
# 1619819      RABL2B      ENST00000691320           715  HC      NaN
# 1620148      RABL2B      ENST00000691320           534  HC      NaN
# 1620665      RABL2B      ENST00000691320           462  HC      NaN
# 1620705      RABL2B      ENST00000691320           413  HC      NaN
# 1620875      RABL2B      ENST00000691320           351  HC      NaN
#
#         LoF_filter   AC
# 199            NaN    1
# 4666           NaN    1
# 4692           NaN    1
# 4728           NaN    2
# 5071           NaN    6
# ...            ...  ...
# 1619819        NaN  173
# 1620148        NaN    1
# 1620665        NaN    1
# 1620705        NaN    2
# 1620875        NaN    2
#
# [300052 rows x 14 columns]

# %% [markdown]
# Удалим все строки, где нет названия транскрипта в "Canonical_transcript" или там стоит два и больше названий:

# %%
lof_final_df = lof_final_df.dropna(subset=['Canonical_transcript'])
lof_final_df = lof_final_df[~lof_final_df['Canonical_transcript'].str.contains(',')]

# %%
lof_final_df
# Out:
#          CHROM       POS          rsID REF ALT Impact  Consequence  \
# 199       chr1     69548  rs1211934440   T   A   HIGH  stop_gained
# 4666      chr1    925933  rs1409697303   A   T   HIGH  stop_gained
# 4692      chr1    925960             .   C   T   HIGH  stop_gained
# 4728      chr1    925996             .   C   T   HIGH  stop_gained
# 5071      chr1    930221   rs934852613   C   T   HIGH  stop_gained
# ...        ...       ...           ...  ..  ..    ...          ...
# 1619819  chr22  50769106   rs559977293   G   A   HIGH  stop_gained
# 1620148  chr22  50769969             .   C   T   HIGH  stop_gained
# 1620665  chr22  50775796  rs1555923164   G   T   HIGH  stop_gained
# 1620705  chr22  50775845             .   C   T   HIGH  stop_gained
# 1620875  chr22  50776725   rs375595282   G   T   HIGH  stop_gained
#
#         Gene_symbol Canonical_transcript cDNA_position LoF LoF_flag  \
# 199           OR4F5      ENST00000641515           581  HC      NaN
# 4666         SAMD11      ENST00000616016          1038  HC      NaN
# 4692         SAMD11      ENST00000616016          1065  HC      NaN
# 4728         SAMD11      ENST00000616016          1101  HC      NaN
# 5071         SAMD11      ENST00000616016          1185  HC      NaN
# ...             ...                  ...           ...  ..      ...
# 1619819      RABL2B      ENST00000691320           715  HC      NaN
# 1620148      RABL2B      ENST00000691320           534  HC      NaN
# 1620665      RABL2B      ENST00000691320           462  HC      NaN
# 1620705      RABL2B      ENST00000691320           413  HC      NaN
# 1620875      RABL2B      ENST00000691320           351  HC      NaN
#
#         LoF_filter   AC
# 199            NaN    1
# 4666           NaN    1
# 4692           NaN    1
# 4728           NaN    2
# 5071           NaN    6
# ...            ...  ...
# 1619819        NaN  173
# 1620148        NaN    1
# 1620665        NaN    1
# 1620705        NaN    2
# 1620875        NaN    2
#
# [300052 rows x 14 columns]

# %%
lof_final_df['Consequence'].unique()
# Out:
# array(['stop_gained'], dtype=object)

# %%
lof_final_df['POS'].nunique()
# Out:
# 296210

# %% [markdown]
# #### Добавляем метрику LOEUF

# %% [markdown]
# The loss-of-function observed over expected upper bound fraction, or LOEUF score, is a metric that places each gene on a continuous scale of loss-of-function constraint. Low scores are highly correlated with disease genes and gene essentiality (https://doi.org/10.1007/s00439-022-02509-x).
#
# Due to expected shifts in the LOEUF distribution between gnomAD v2.1.1 and v4.0, we now recommend a threshold of LOEUF < 0.6 for v4.0 (compared to LOEUF < 0.35 for v2). (https://gnomad.broadinstitute.org/news/2024-03-gnomad-v4-0-gene-constraint/#loeuf-guidance)

# %% [markdown]
# Для этого сначала переводим скачанный файл с метриками в датафрейм.

# %%
lof_metrics_by_gene = pd.read_table('../raw_data/plof_metrics/gnomad.v2.1.1.lof_metrics.by_gene.txt')
lof_metrics_by_gene
# Out:
#          gene       transcript  obs_mis  exp_mis   oe_mis    mu_mis  \
# 0       MED13  ENST00000397786      871  1117.80  0.77921  0.000056
# 1       NIPBL  ENST00000282516      846  1441.50  0.58688  0.000074
# 2        SMC3  ENST00000361804      178   630.07  0.28251  0.000032
# 3       CNOT1  ENST00000317147      561  1295.90  0.43290  0.000069
# 4         RLF  ENST00000372771      669   972.87  0.68766  0.000047
# ...       ...              ...      ...      ...      ...       ...
# 19699   OR7G2  ENST00000305456      177   181.12  0.97723  0.000009
# 19700   OR7G3  ENST00000305444      164   163.92  1.00050  0.000008
# 19701   OR8D1  ENST00000357821      178   162.04  1.09850  0.000008
# 19702  ZNF600  ENST00000338230      450   357.84  1.25750  0.000018
# 19703  ZNF645  ENST00000323684      168   179.70  0.93491  0.000015
#
#        possible_mis  obs_mis_pphen  exp_mis_pphen  oe_mis_pphen  ...  \
# 0             14195          314.0        529.750       0.59273  ...
# 1             18540          158.0        543.100       0.29092  ...
# 2              8109           21.0        182.520       0.11506  ...
# 3             15670           51.0        290.680       0.17545  ...
# 4             12682          107.0        321.140       0.33319  ...
# ...             ...            ...            ...           ...  ...
# 19699          2247           34.0         38.175       0.89064  ...
# 19700          2016           40.0         39.403       1.01520  ...
# 19701          2002           65.0         54.179       1.19970  ...
# 19702          4794          138.0        124.070       1.11220  ...
# 19703          2787           18.0         19.718       0.91287  ...
#
#             gene_type  gene_length      exac_pLI  exac_obs_lof  exac_exp_lof  \
# 0      protein_coding       122678  1.000000e+00           0.0       64.3930
# 1      protein_coding       189655  1.000000e+00           1.0      110.5700
# 2      protein_coding        36946  1.000000e+00           0.0       58.5230
# 3      protein_coding       109936  1.000000e+00           3.0       90.1300
# 4      protein_coding        79549  1.000000e+00           0.0       43.6070
# ...               ...          ...           ...           ...           ...
# 19699  protein_coding         1038  7.093800e-03           3.0        2.9635
# 19700  protein_coding          939  4.059600e-01           1.0        4.8401
# 19701  protein_coding         1026  2.159200e-01           1.0        2.7436
# 19702  protein_coding        22597  1.477300e-13          16.0        9.6420
# 19703  protein_coding         1510  1.646600e-02           4.0        8.2529
#
#        exac_oe_lof  brain_expression  chromosome  start_position  end_position
# 0         0.000000               NaN          17        60019966      60142643
# 1         0.009044               NaN           5        36876861      37066515
# 2         0.000000               NaN          10       112327449     112364394
# 3         0.033285               NaN          16        58553855      58663790
# 4         0.000000               NaN           1        40627045      40706593
# ...            ...               ...         ...             ...           ...
# 19699     1.012300               NaN          19         9212945       9213982
# 19700     0.206610               NaN          19         9236688       9237626
# 19701     0.364480               NaN          11       124179708     124180733
# 19702     1.659400               NaN          19        53267448      53290044
# 19703     0.484680               NaN           X        22291065      22292574
#
# [19704 rows x 77 columns]

# %%
lof_metrics_by_gene.columns
# Out:
# Index(['gene', 'transcript', 'obs_mis', 'exp_mis', 'oe_mis', 'mu_mis',
#        'possible_mis', 'obs_mis_pphen', 'exp_mis_pphen', 'oe_mis_pphen',
#        'possible_mis_pphen', 'obs_syn', 'exp_syn', 'oe_syn', 'mu_syn',
#        'possible_syn', 'obs_lof', 'mu_lof', 'possible_lof', 'exp_lof', 'pLI',
#        'pNull', 'pRec', 'oe_lof', 'oe_syn_lower', 'oe_syn_upper',
#        'oe_mis_lower', 'oe_mis_upper', 'oe_lof_lower', 'oe_lof_upper',
#        'constraint_flag', 'syn_z', 'mis_z', 'lof_z', 'oe_lof_upper_rank',
#        'oe_lof_upper_bin', 'oe_lof_upper_bin_6', 'n_sites', 'classic_caf',
#        'max_af', 'no_lofs', 'obs_het_lof', 'obs_hom_lof', 'defined', 'p',
#        'exp_hom_lof', 'classic_caf_afr', 'classic_caf_amr', 'classic_caf_asj',
#        'classic_caf_eas', 'classic_caf_fin', 'classic_caf_nfe',
#        'classic_caf_oth', 'classic_caf_sas', 'p_afr', 'p_amr', 'p_asj',
#        'p_eas', 'p_fin', 'p_nfe', 'p_oth', 'p_sas', 'transcript_type',
#        'gene_id', 'transcript_level', 'cds_length', 'num_coding_exons',
#        'gene_type', 'gene_length', 'exac_pLI', 'exac_obs_lof', 'exac_exp_lof',
#        'exac_oe_lof', 'brain_expression', 'chromosome', 'start_position',
#        'end_position'],
#       dtype='object')

# %%
lof_metrics_by_gene.columns.get_loc('oe_lof_upper')
# Out:
# 29

# %% [markdown]
# Создаем словарь "транскрипт": "значение_loeuf".

# %%
loeuf_by_transcript_dict = dict(zip(lof_metrics_by_gene['transcript'], lof_metrics_by_gene['oe_lof_upper']))

# %%
# loeuf_by_transcript_dict

# %% [markdown]
# Запишем в столбец LOEUF все совпадения по ключам-транскриптам.

# %%
lof_final_df.loc[:, 'LOEUF'] = lof_final_df['Canonical_transcript'].map(loeuf_by_transcript_dict)

# %%
lof_final_df
# Out:
#          CHROM       POS          rsID REF ALT Impact  Consequence  \
# 199       chr1     69548  rs1211934440   T   A   HIGH  stop_gained
# 4666      chr1    925933  rs1409697303   A   T   HIGH  stop_gained
# 4692      chr1    925960             .   C   T   HIGH  stop_gained
# 4728      chr1    925996             .   C   T   HIGH  stop_gained
# 5071      chr1    930221   rs934852613   C   T   HIGH  stop_gained
# ...        ...       ...           ...  ..  ..    ...          ...
# 1619819  chr22  50769106   rs559977293   G   A   HIGH  stop_gained
# 1620148  chr22  50769969             .   C   T   HIGH  stop_gained
# 1620665  chr22  50775796  rs1555923164   G   T   HIGH  stop_gained
# 1620705  chr22  50775845             .   C   T   HIGH  stop_gained
# 1620875  chr22  50776725   rs375595282   G   T   HIGH  stop_gained
#
#         Gene_symbol Canonical_transcript cDNA_position LoF LoF_flag  \
# 199           OR4F5      ENST00000641515           581  HC      NaN
# 4666         SAMD11      ENST00000616016          1038  HC      NaN
# 4692         SAMD11      ENST00000616016          1065  HC      NaN
# 4728         SAMD11      ENST00000616016          1101  HC      NaN
# 5071         SAMD11      ENST00000616016          1185  HC      NaN
# ...             ...                  ...           ...  ..      ...
# 1619819      RABL2B      ENST00000691320           715  HC      NaN
# 1620148      RABL2B      ENST00000691320           534  HC      NaN
# 1620665      RABL2B      ENST00000691320           462  HC      NaN
# 1620705      RABL2B      ENST00000691320           413  HC      NaN
# 1620875      RABL2B      ENST00000691320           351  HC      NaN
#
#         LoF_filter   AC  LOEUF
# 199            NaN    1    NaN
# 4666           NaN    1    NaN
# 4692           NaN    1    NaN
# 4728           NaN    2    NaN
# 5071           NaN    6    NaN
# ...            ...  ...    ...
# 1619819        NaN  173    NaN
# 1620148        NaN    1    NaN
# 1620665        NaN    1    NaN
# 1620705        NaN    2    NaN
# 1620875        NaN    2    NaN
#
# [300052 rows x 15 columns]

# %% [markdown]
# Посмотрим, какие значения записались и сверим, совпадает ли с исходным файлом **(upd: да)**

# %%
lof_final_df[lof_final_df['LOEUF'].notna()]
# Out:
#          CHROM       POS          rsID REF ALT Impact  Consequence  \
# 13302     chr1    951173             .   G   T   HIGH  stop_gained
# 13323     chr1    951207   rs967128892   G   A   HIGH  stop_gained
# 13329     chr1    951214  rs1181426236   G   C   HIGH  stop_gained
# 13625     chr1    952022  rs1399402693   G   A   HIGH  stop_gained
# 13676     chr1    952087             .   C   T   HIGH  stop_gained
# ...        ...       ...           ...  ..  ..    ...          ...
# 1618565  chr22  50744863   rs372608841   C   T   HIGH  stop_gained
# 1618575  chr22  50744878   rs776906749   C   T   HIGH  stop_gained
# 1618614  chr22  50744938  rs1327549675   C   T   HIGH  stop_gained
# 1618624  chr22  50744953   rs769944788   C   T   HIGH  stop_gained
# 1618696  chr22  50745079             .   C   T   HIGH  stop_gained
#
#         Gene_symbol Canonical_transcript cDNA_position LoF LoF_flag  \
# 13302         NOC2L      ENST00000327044          1413  HC      NaN
# 13323         NOC2L      ENST00000327044          1379  HC      NaN
# 13329         NOC2L      ENST00000327044          1372  HC      NaN
# 13625         NOC2L      ENST00000327044          1325  HC      NaN
# 13676         NOC2L      ENST00000327044          1260  HC      NaN
# ...             ...                  ...           ...  ..      ...
# 1618565         ACR      ENST00000216139           954  LC      NaN
# 1618575         ACR      ENST00000216139           969  LC      NaN
# 1618614         ACR      ENST00000216139          1029  LC      NaN
# 1618624         ACR      ENST00000216139          1044  LC      NaN
# 1618696         ACR      ENST00000216139          1170  LC      NaN
#
#         LoF_filter  AC  LOEUF
# 13302          NaN   2  1.327
# 13323          NaN  53  1.327
# 13329          NaN   1  1.327
# 13625          NaN   4  1.327
# 13676          NaN   2  1.327
# ...            ...  ..    ...
# 1618565  END_TRUNC   6  0.880
# 1618575  END_TRUNC   9  0.880
# 1618614  END_TRUNC   4  0.880
# 1618624  END_TRUNC  13  0.880
# 1618696  END_TRUNC   1  0.880
#
# [210663 rows x 15 columns]

# %%
print(lof_metrics_by_gene.loc[lof_metrics_by_gene['transcript'] == 'ENST00000327044', 'oe_lof_upper'].values[0], '\n',
lof_metrics_by_gene.loc[lof_metrics_by_gene['transcript'] == 'ENST00000216139', 'oe_lof_upper'].values[0])
# Out:
# 1.327
#  0.88

# %%
print(lof_metrics_by_gene.loc[lof_metrics_by_gene['transcript'] == 'ENST00000370783', 'oe_lof_upper'].values[0], '\n',
lof_metrics_by_gene.loc[lof_metrics_by_gene['transcript'] == 'ENST00000262213', 'oe_lof_upper'].values[0])
# Out:
# 0.361
#  0.361

# %% [markdown]
# Удалим все строки, где нет LOEUF (т.к. для нас они бессмысленны и всё равно удалятся при делении на пат/бен):

# %%
lof_final_df = lof_final_df.dropna(subset=['LOEUF'])

# %%
lof_final_df.shape
# Out:
# (210663, 15)

# %% [markdown]
# Оставляем только высококонсервативные варианты:

# %%
lof_final_df = lof_final_df[lof_final_df['LOEUF'] < 0.35]

# %%
lof_final_df.shape
# Out:
# (24389, 15)

# %% [markdown]
# #### Добавляем метрику pext

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10029069/

# %%
header_pext = ['chrom', 'pos', 'ref', 'alt', 'tx_annotation']

# %% [markdown]
# Выгружаем и обрабатываем отфильтрованный файл (внутри только стопгейны):

# %%
pext_raw_df = pd.read_table("data_dir/pext/stop_gained_rows.tsv", names=header_pext)
# Out:
# /tmp/ipykernel_3118914/4201993334.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   pext_raw_df = pd.read_table("data_dir/pext/stop_gained_rows.tsv", names=header_pext)

# %%
tx_annotation_data = pext_raw_df['tx_annotation'].apply(lambda x: json.loads(x.replace("'", "\""))[0])
pext_tx_annotation = pd.DataFrame(tx_annotation_data.tolist())
pext_hg19_df = pd.concat([pext_raw_df.drop(columns=['tx_annotation']), pext_tx_annotation], axis=1)

# %%
pext_hg19_df = pext_hg19_df[(pext_hg19_df['chrom'] != 'X') & (pext_hg19_df['chrom'] != 'Y')]

# %%
pext_hg19_df
# Out:
#         chrom       pos ref alt             ensg          csq  symbol lof  \
# 0           1     69100   G   T  ENSG00000186092  stop_gained   OR4F5  HC
# 1           1     69130   C   T  ENSG00000186092  stop_gained   OR4F5  HC
# 2           1     69133   G   T  ENSG00000186092  stop_gained   OR4F5  HC
# 3           1     69139   C   T  ENSG00000186092  stop_gained   OR4F5  HC
# 4           1     69158   T   A  ENSG00000186092  stop_gained   OR4F5  HC
# ...       ...       ...  ..  ..              ...          ...     ...  ..
# 4190799    22  51220691   A   T  ENSG00000079974  stop_gained  RABL2B  HC
# 4190800    22  51220695   C   A  ENSG00000079974  stop_gained  RABL2B  HC
# 4190801    22  51220704   T   A  ENSG00000079974  stop_gained  RABL2B  HC
# 4190802    22  51220710   T   A  ENSG00000079974  stop_gained  RABL2B  HC
# 4190803    22  51220716   C   A  ENSG00000079974  stop_gained  RABL2B  HC
#
#             lof_flag Cells_Transformedfibroblasts  ...  \
# 0        SINGLE_EXON                          NaN  ...
# 1        SINGLE_EXON                          NaN  ...
# 2        SINGLE_EXON                          NaN  ...
# 3        SINGLE_EXON                          NaN  ...
# 4        SINGLE_EXON                          NaN  ...
# ...              ...                          ...  ...
# 4190799         None                     0.657611  ...
# 4190800         None                     0.657611  ...
# 4190801         None                     0.657611  ...
# 4190802         None                     0.657611  ...
# 4190803         None                     0.657611  ...
#
#         Brain_Anteriorcingulatecortex_BA24_ Brain_Putamen_basalganglia_  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# ...                                     ...                         ...
# 4190799                            0.649823                    0.558983
# 4190800                            0.649823                    0.558983
# 4190801                            0.649823                    0.558983
# 4190802                            0.649823                    0.558983
# 4190803                            0.649823                    0.558983
#
#         Brain_Caudate_basalganglia_ Colon_Sigmoid Cervix_Endocervix     Ovary  \
# 0                               NaN           NaN               NaN       NaN
# 1                               NaN           NaN               NaN       NaN
# 2                               NaN           NaN               NaN       NaN
# 3                               NaN           NaN               NaN       NaN
# 4                               NaN           NaN               NaN       NaN
# ...                             ...           ...               ...       ...
# 4190799                    0.593938      0.482771          0.477411  0.455952
# 4190800                    0.593938      0.482771          0.477411  0.455952
# 4190801                    0.593938      0.482771          0.477411  0.455952
# 4190802                    0.593938      0.482771          0.477411  0.455952
# 4190803                    0.593938      0.482771          0.477411  0.455952
#
#         Esophagus_GastroesophagealJunction    Testis Brain_Amygdala  \
# 0                                      NaN       NaN            NaN
# 1                                      NaN       NaN            NaN
# 2                                      NaN       NaN            NaN
# 3                                      NaN       NaN            NaN
# 4                                      NaN       NaN            NaN
# ...                                    ...       ...            ...
# 4190799                           0.511429  0.564813       0.582428
# 4190800                           0.511429  0.564813       0.582428
# 4190801                           0.511429  0.564813       0.582428
# 4190802                           0.511429  0.564813       0.582428
# 4190803                           0.511429  0.564813       0.582428
#
#         mean_proportion
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4190799        0.506288
# 4190800        0.506288
# 4190801        0.506288
# 4190802        0.506288
# 4190803        0.506288
#
# [4190804 rows x 63 columns]

# %% [markdown]
# Переводим в hg38:

# %%
pext_hg38_df = pext_hg19_df.copy()
pext_hg38_df['chrom'] = pext_hg38_df['chrom'].apply(lambda x: 'chr' + str(x))

# %%
pext_hg38_df
# Out:
#          chrom       pos ref alt             ensg          csq  symbol lof  \
# 0         chr1     69100   G   T  ENSG00000186092  stop_gained   OR4F5  HC
# 1         chr1     69130   C   T  ENSG00000186092  stop_gained   OR4F5  HC
# 2         chr1     69133   G   T  ENSG00000186092  stop_gained   OR4F5  HC
# 3         chr1     69139   C   T  ENSG00000186092  stop_gained   OR4F5  HC
# 4         chr1     69158   T   A  ENSG00000186092  stop_gained   OR4F5  HC
# ...        ...       ...  ..  ..              ...          ...     ...  ..
# 4190799  chr22  51220691   A   T  ENSG00000079974  stop_gained  RABL2B  HC
# 4190800  chr22  51220695   C   A  ENSG00000079974  stop_gained  RABL2B  HC
# 4190801  chr22  51220704   T   A  ENSG00000079974  stop_gained  RABL2B  HC
# 4190802  chr22  51220710   T   A  ENSG00000079974  stop_gained  RABL2B  HC
# 4190803  chr22  51220716   C   A  ENSG00000079974  stop_gained  RABL2B  HC
#
#             lof_flag Cells_Transformedfibroblasts  ...  \
# 0        SINGLE_EXON                          NaN  ...
# 1        SINGLE_EXON                          NaN  ...
# 2        SINGLE_EXON                          NaN  ...
# 3        SINGLE_EXON                          NaN  ...
# 4        SINGLE_EXON                          NaN  ...
# ...              ...                          ...  ...
# 4190799         None                     0.657611  ...
# 4190800         None                     0.657611  ...
# 4190801         None                     0.657611  ...
# 4190802         None                     0.657611  ...
# 4190803         None                     0.657611  ...
#
#         Brain_Anteriorcingulatecortex_BA24_ Brain_Putamen_basalganglia_  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# ...                                     ...                         ...
# 4190799                            0.649823                    0.558983
# 4190800                            0.649823                    0.558983
# 4190801                            0.649823                    0.558983
# 4190802                            0.649823                    0.558983
# 4190803                            0.649823                    0.558983
#
#         Brain_Caudate_basalganglia_ Colon_Sigmoid Cervix_Endocervix     Ovary  \
# 0                               NaN           NaN               NaN       NaN
# 1                               NaN           NaN               NaN       NaN
# 2                               NaN           NaN               NaN       NaN
# 3                               NaN           NaN               NaN       NaN
# 4                               NaN           NaN               NaN       NaN
# ...                             ...           ...               ...       ...
# 4190799                    0.593938      0.482771          0.477411  0.455952
# 4190800                    0.593938      0.482771          0.477411  0.455952
# 4190801                    0.593938      0.482771          0.477411  0.455952
# 4190802                    0.593938      0.482771          0.477411  0.455952
# 4190803                    0.593938      0.482771          0.477411  0.455952
#
#         Esophagus_GastroesophagealJunction    Testis Brain_Amygdala  \
# 0                                      NaN       NaN            NaN
# 1                                      NaN       NaN            NaN
# 2                                      NaN       NaN            NaN
# 3                                      NaN       NaN            NaN
# 4                                      NaN       NaN            NaN
# ...                                    ...       ...            ...
# 4190799                           0.511429  0.564813       0.582428
# 4190800                           0.511429  0.564813       0.582428
# 4190801                           0.511429  0.564813       0.582428
# 4190802                           0.511429  0.564813       0.582428
# 4190803                           0.511429  0.564813       0.582428
#
#         mean_proportion
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4190799        0.506288
# 4190800        0.506288
# 4190801        0.506288
# 4190802        0.506288
# 4190803        0.506288
#
# [4190804 rows x 63 columns]

# %%
lo = pyliftover.LiftOver('hg19', 'hg38')

for index, row in pext_hg38_df.iterrows():
    try:
        converted = lo.convert_coordinate(row['chrom'], row['pos'])
        if converted:
            pext_hg38_df.loc[index, 'chrom'] = converted[0][0]
            pext_hg38_df.loc[index, 'pos'] = converted[0][1]
    except Exception as e:
        print(f"Error converting coordinates for index {index}: {e}")

# %%
# cols_to_avg = ['Cells_Transformedfibroblasts', 'Prostate', 'Spleen',
#        'Brain_FrontalCortex_BA9_', 'SmallIntestine_TerminalIleum',
#        'MinorSalivaryGland', 'Artery_Coronary', 'Skin_SunExposed_Lowerleg_',
#        'Cells_EBV_transformedlymphocytes', 'Brain_Hippocampus',
#        'Esophagus_Muscularis', 'Brain_Nucleusaccumbens_basalganglia_',
#        'Artery_Tibial', 'Brain_Hypothalamus', 'Adipose_Visceral_Omentum_',
#        'Cervix_Ectocervix', 'Brain_Spinalcord_cervicalc_1_',
#        'Brain_CerebellarHemisphere', 'Nerve_Tibial', 'Breast_MammaryTissue',
#        'Liver', 'Skin_NotSunExposed_Suprapubic_', 'AdrenalGland', 'Vagina',
#        'Pancreas', 'Lung', 'FallopianTube', 'Pituitary', 'Muscle_Skeletal',
#        'Colon_Transverse', 'Artery_Aorta', 'Heart_AtrialAppendage',
#        'Adipose_Subcutaneous', 'Esophagus_Mucosa', 'Heart_LeftVentricle',
#        'Brain_Cerebellum', 'Brain_Cortex', 'Thyroid', 'Brain_Substantianigra',
#        'Kidney_Cortex', 'Uterus', 'Stomach', 'WholeBlood', 'Bladder',
#        'Brain_Anteriorcingulatecortex_BA24_', 'Brain_Putamen_basalganglia_',
#        'Brain_Caudate_basalganglia_', 'Colon_Sigmoid', 'Cervix_Endocervix',
#        'Ovary', 'Esophagus_GastroesophagealJunction', 'Testis',
#        'Brain_Amygdala']

# row_index = 4190803

# pext_hg38_df.loc[row_index, cols_to_avg].mean(skipna=True)  # совпадает с mean_proportion

# %%
pext_dict = {(row['chrom'], row['pos'], row['ref'], row['alt']): row['mean_proportion'] for _, row in pext_hg38_df.iterrows()}

# %%
len(pext_dict)  # исчезли строки, где все NaN
# Out:
# 4184730

# %%
for index, row in lof_final_df.iterrows():
    key = (row['CHROM'], row['POS'], row['REF'], row['ALT'])
    
    if key in pext_dict:
        lof_final_df.loc[index, 'pext'] = pext_dict[key]
    else:
        lof_final_df.loc[index, 'pext'] = None
# Out:
# /tmp/ipykernel_3118914/201323663.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   lof_final_df.loc[index, 'pext'] = pext_dict[key]

# %%
lof_final_df['pext'].notna().sum()
# Out:
# 24345

# %%
lof_final_df.shape
# Out:
# (24389, 16)

# %% [markdown]
# Оставляем только более высокоэкспрессирующиеся варианты:

# %%
lof_final_df['pext'] = lof_final_df['pext'].astype(float)
lof_final_df = lof_final_df[lof_final_df['pext'] > 0.5]

# %%
lof_final_df.shape
# Out:
# (17163, 16)

# %%
lof_final_df['pext'].notna().sum()
# Out:
# 17163

# %% [markdown]
# #### Получение NMD(-) регионов

# %% [markdown]
# Тестим nmd-escape из статьи Torene et al., 2024
#
# https://doi.org/10.1016/j.ajhg.2023.11.007
# https://github.com/rebeccaito/nmd-escape/tree/main

# %%
from annotating_nmd import *

# %% [markdown]
# Получаем нужный bed-файл.

# %% [markdown]
# ! `zcat gencode.v45.annotation.gtf.gz | awk 'OFS="\t" {if ($3=="CDS") {print $1,$4-1,$5,$12,$6,$7}}' | tr -d '";' > gencode.v45.annotation.bed`

# %%
cds_bed_df = pd.read_table('data_dir/gencode_data/gencode.v45.annotation.bed', names=['chrom', 'start', 'end', 'cds_id', 'score', 'strand'])

cds_bed_df['cds_id'] = (cds_bed_df['cds_id'] + '_cds_0_0_' +
                              cds_bed_df['chrom'] + '_' +
                              (cds_bed_df['start'] + 1).astype(str) + '_' +
                              cds_bed_df['strand'].map({'+': 'f', '-': 'r'}))

# %%
cds_bed_df
# Out:
#        chrom   start     end                                   cds_id score  \
# 0       chr1   65564   65573   ENST00000641515.2_cds_0_0_chr1_65565_f     .
# 1       chr1   69036   70005   ENST00000641515.2_cds_0_0_chr1_69037_f     .
# 2       chr1  450742  451678  ENST00000426406.4_cds_0_0_chr1_450743_r     .
# 3       chr1  685718  686654  ENST00000332831.5_cds_0_0_chr1_685719_r     .
# 4       chr1  924431  924948  ENST00000616016.5_cds_0_0_chr1_924432_f     .
# ...      ...     ...     ...                                      ...   ...
# 885744  chrM   10469   10763   ENST00000361335.1_cds_0_0_chrM_10470_f     .
# 885745  chrM   10759   12137   ENST00000361381.2_cds_0_0_chrM_10760_f     .
# 885746  chrM   12336   14145   ENST00000361567.2_cds_0_0_chrM_12337_f     .
# 885747  chrM   14148   14673   ENST00000361681.2_cds_0_0_chrM_14149_r     .
# 885748  chrM   14746   15887   ENST00000361789.2_cds_0_0_chrM_14747_f     .
#
#        strand
# 0           +
# 1           +
# 2           -
# 3           -
# 4           +
# ...       ...
# 885744      +
# 885745      +
# 885746      +
# 885747      -
# 885748      +
#
# [885749 rows x 6 columns]

# %% [markdown]
# Determine NMD regions from a 6-column bed file of coding sequence regions:

# %%
nmd_bed_df = make_boundaries_df(cds_bed_df)

# %%
nmd_bed_df
# Out:
#                        index  chrom      start        end  \
# transcript_name
# ENST00000000233.10 0  358020   chr7  127591212  127591296
#                    1  358019   chr7  127591033  127591088
# ENST00000000412.8  0  528168  chr12    8941820    8941940
#                    1  528167  chr12    8942415    8942470
# ENST00000000442.11 0  493539  chr11   64315706   64315963
# ...                      ...    ...        ...        ...
# ENST00000713920.1  1  649116  chr16    1320462    1320517
# ENST00000713921.1  0  649156  chr16    1324729    1324790
#                    1  649155  chr16    1320462    1320517
# ENST00000713922.1  0  649327  chr16    1314756    1314858
#                    1  649326  chr16    1314321    1314376
#
#                                                            cds_id score  \
# transcript_name
# ENST00000000233.10 0  ENST00000000233.10_cds_0_0_chr7_127591213_f     .
#                    1  ENST00000000233.10_cds_0_0_chr7_127590963_f     .
# ENST00000000412.8  0    ENST00000000412.8_cds_0_0_chr12_8941821_r     .
#                    1    ENST00000000412.8_cds_0_0_chr12_8942416_r     .
# ENST00000000442.11 0  ENST00000000442.11_cds_0_0_chr11_64315707_f     .
# ...                                                           ...   ...
# ENST00000713920.1  1    ENST00000713920.1_cds_0_0_chr16_1320438_f     .
# ENST00000713921.1  0    ENST00000713921.1_cds_0_0_chr16_1324730_f     .
#                    1    ENST00000713921.1_cds_0_0_chr16_1320438_f     .
# ENST00000713922.1  0    ENST00000713922.1_cds_0_0_chr16_1314757_f     .
#                    1    ENST00000713922.1_cds_0_0_chr16_1314293_f     .
#
#                      strand     transcript_name cds_size
# transcript_name
# ENST00000000233.10 0      +  ENST00000000233.10       84
#                    1      +  ENST00000000233.10       55
# ENST00000000412.8  0      -   ENST00000000412.8      120
#                    1      -   ENST00000000412.8       55
# ENST00000000442.11 0      +  ENST00000000442.11      257
# ...                     ...                 ...      ...
# ENST00000713920.1  1      +   ENST00000713920.1       55
# ENST00000713921.1  0      +   ENST00000713921.1       61
#                    1      +   ENST00000713921.1       55
# ENST00000713922.1  0      +   ENST00000713922.1      102
#                    1      +   ENST00000713922.1       55
#
# [213979 rows x 9 columns]

# %% [markdown]
# #### Добавление статуса NMD в датафрейм

# %% [markdown]
# Для удобства уберем группировку по `transcript_name`:

# %%
nmd_bed_df
# Out:
#                        index  chrom      start        end  \
# transcript_name
# ENST00000000233.10 0  358020   chr7  127591212  127591296
#                    1  358019   chr7  127591033  127591088
# ENST00000000412.8  0  528168  chr12    8941820    8941940
#                    1  528167  chr12    8942415    8942470
# ENST00000000442.11 0  493539  chr11   64315706   64315963
# ...                      ...    ...        ...        ...
# ENST00000713920.1  1  649116  chr16    1320462    1320517
# ENST00000713921.1  0  649156  chr16    1324729    1324790
#                    1  649155  chr16    1320462    1320517
# ENST00000713922.1  0  649327  chr16    1314756    1314858
#                    1  649326  chr16    1314321    1314376
#
#                                                            cds_id score  \
# transcript_name
# ENST00000000233.10 0  ENST00000000233.10_cds_0_0_chr7_127591213_f     .
#                    1  ENST00000000233.10_cds_0_0_chr7_127590963_f     .
# ENST00000000412.8  0    ENST00000000412.8_cds_0_0_chr12_8941821_r     .
#                    1    ENST00000000412.8_cds_0_0_chr12_8942416_r     .
# ENST00000000442.11 0  ENST00000000442.11_cds_0_0_chr11_64315707_f     .
# ...                                                           ...   ...
# ENST00000713920.1  1    ENST00000713920.1_cds_0_0_chr16_1320438_f     .
# ENST00000713921.1  0    ENST00000713921.1_cds_0_0_chr16_1324730_f     .
#                    1    ENST00000713921.1_cds_0_0_chr16_1320438_f     .
# ENST00000713922.1  0    ENST00000713922.1_cds_0_0_chr16_1314757_f     .
#                    1    ENST00000713922.1_cds_0_0_chr16_1314293_f     .
#
#                      strand     transcript_name cds_size
# transcript_name
# ENST00000000233.10 0      +  ENST00000000233.10       84
#                    1      +  ENST00000000233.10       55
# ENST00000000412.8  0      -   ENST00000000412.8      120
#                    1      -   ENST00000000412.8       55
# ENST00000000442.11 0      +  ENST00000000442.11      257
# ...                     ...                 ...      ...
# ENST00000713920.1  1      +   ENST00000713920.1       55
# ENST00000713921.1  0      +   ENST00000713921.1       61
#                    1      +   ENST00000713921.1       55
# ENST00000713922.1  0      +   ENST00000713922.1      102
#                    1      +   ENST00000713922.1       55
#
# [213979 rows x 9 columns]

# %%
nmd_bed_df = nmd_bed_df.rename(columns={'transcript_name': 'transcript'})
nmd_bed_df = nmd_bed_df.reset_index()
nmd_bed_df = nmd_bed_df.drop('transcript_name', axis=1)

# %%
nmd_bed_df = nmd_bed_df.drop('level_1', axis=1)

# %%
nmd_bed_df = nmd_bed_df.drop('index', axis=1)

# %%
nmd_bed_df
# Out:
#         chrom      start        end  \
# 0        chr7  127591212  127591296
# 1        chr7  127591033  127591088
# 2       chr12    8941820    8941940
# 3       chr12    8942415    8942470
# 4       chr11   64315706   64315963
# ...       ...        ...        ...
# 213974  chr16    1320462    1320517
# 213975  chr16    1324729    1324790
# 213976  chr16    1320462    1320517
# 213977  chr16    1314756    1314858
# 213978  chr16    1314321    1314376
#
#                                              cds_id score strand  \
# 0       ENST00000000233.10_cds_0_0_chr7_127591213_f     .      +
# 1       ENST00000000233.10_cds_0_0_chr7_127590963_f     .      +
# 2         ENST00000000412.8_cds_0_0_chr12_8941821_r     .      -
# 3         ENST00000000412.8_cds_0_0_chr12_8942416_r     .      -
# 4       ENST00000000442.11_cds_0_0_chr11_64315707_f     .      +
# ...                                             ...   ...    ...
# 213974    ENST00000713920.1_cds_0_0_chr16_1320438_f     .      +
# 213975    ENST00000713921.1_cds_0_0_chr16_1324730_f     .      +
# 213976    ENST00000713921.1_cds_0_0_chr16_1320438_f     .      +
# 213977    ENST00000713922.1_cds_0_0_chr16_1314757_f     .      +
# 213978    ENST00000713922.1_cds_0_0_chr16_1314293_f     .      +
#
#                 transcript cds_size
# 0       ENST00000000233.10       84
# 1       ENST00000000233.10       55
# 2        ENST00000000412.8      120
# 3        ENST00000000412.8       55
# 4       ENST00000000442.11      257
# ...                    ...      ...
# 213974   ENST00000713920.1       55
# 213975   ENST00000713921.1       61
# 213976   ENST00000713921.1       55
# 213977   ENST00000713922.1      102
# 213978   ENST00000713922.1       55
#
# [213979 rows x 8 columns]

# %% [markdown]
# Ищем совпадение по транскрипту. Если найдено, проверяем, попадает ли позиция в границы.

# %%
# %%time

mask_transcript = lof_final_df['Canonical_transcript'].isin(nmd_bed_df['transcript'].str.split('.').str[0])
lof_final_df.loc[~mask_transcript, 'NMD_escape'] = 'NO_TRANSCRIPT'

for index, row in nmd_bed_df.iterrows():
    transcript_split = row['transcript'].split('.')[0]
    
    mask_all = (lof_final_df['Canonical_transcript'] == transcript_split) & \
             (lof_final_df['POS'] >= row['start']) & \
             (lof_final_df['POS'] <= row['end'])
    
    lof_final_df.loc[mask_all, 'NMD_escape'] = 'YES'


lof_final_df.loc[(lof_final_df['NMD_escape'] != 'YES') & (lof_final_df['NMD_escape'] != 'NO_TRANSCRIPT'), 'NMD_escape'] = 'NO'
# Out:
# CPU times: user 5min 2s, sys: 744 ms, total: 5min 3s
# Wall time: 5min 5s

# %%
lof_final_df['NMD_escape'].value_counts()
# Out:
# NMD_escape
# NO               14343
# YES               2818
# NO_TRANSCRIPT        2
# Name: count, dtype: int64

# %%
#lof_final_df.to_csv('lof_final_df_nmd.csv', index=False)

# %%
nmd_counts = lof_final_df['NMD_escape'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(nmd_counts, 
        labels=nmd_counts.index, 
        autopct='%1.1f%%', 
        startangle=140,
        colors=sns.color_palette("Spectral")) 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Разделение на NMD(+) и NMD(-) датафреймы

# %%
nmd_esc_df = lof_final_df[lof_final_df['NMD_escape'] == 'YES']
nmd_df = lof_final_df[lof_final_df['NMD_escape'] == 'NO']

# %%
nmd_esc_df.shape  # избегают NMD
# Out:
# (2818, 17)

# %%
nmd_df.shape  # попадают под NMD
# Out:
# (14343, 17)

# %% [markdown]
# ### Разделение вариантов по значению патогенности

# %% [markdown]
# Для начала создадим датафреймы для пат/непат (условно).

# %% [markdown]
# * **условно патогенные**
#    Отсечка в AC < 2. Плюс можно пересечь с ClinVar и записать в список варианты пат/лпат, которые отсутcтвуют в GnomAD v.4, но есть в ClinVar, так мы расширим список патов.
#
# * **условно доброкачественные**
#   Отсечка в AC >= 2 (согласно свежим рекомендациям ACGS, критерий BS2). В таком случае у нас может остаться много АР вариантов, их я предлагаю убрать. Для этого можно полученный условно доброкачественный список сопоставить с ClinVar и удалить все пересечения с зарегистрированными пат/лпат вариантами.

# %% [markdown]
# В ClinVar не указаны транскрипты, поэтому проаннотируем скачанный файл Clinvar (версия для GRCh38) с помощью vep.
# `./vep -i ../clinvar/clinvar_20240331.vcf -o ../clinvar/clinvar_20240331_anno.vcf --vcf --canonical --cache`

# %% [markdown]
# #### Разделение по AC

# %% [markdown]
# Разнесём общий датафрейм (здесь `nmd_df`) на `pat_nmd` и `ben_nmd`.

# %% [markdown]
# **Условно патогенные**:

# %%
pat_nmd = nmd_df.query('AC < 2')
pat_nmd
# Out:
#          CHROM       POS         rsID REF ALT Impact  Consequence Gene_symbol  \
# 174506    chr1   1825438  rs867938404   G   A   HIGH  stop_gained        GNB1
# 190838    chr1   2019468            .   C   A   HIGH  stop_gained       GABRD
# 191152    chr1   2024966            .   C   A   HIGH  stop_gained       GABRD
# 191153    chr1   2024966            .   C   G   HIGH  stop_gained       GABRD
# 191172    chr1   2024993            .   G   A   HIGH  stop_gained       GABRD
# ...        ...       ...          ...  ..  ..    ...          ...         ...
# 1613988  chr22  50720377            .   C   A   HIGH  stop_gained      SHANK3
# 1614099  chr22  50720479            .   T   A   HIGH  stop_gained      SHANK3
# 1614606  chr22  50720939            .   G   T   HIGH  stop_gained      SHANK3
# 1614829  chr22  50721176            .   C   T   HIGH  stop_gained      SHANK3
# 1615796  chr22  50722415            .   A   T   HIGH  stop_gained      SHANK3
#
#         Canonical_transcript cDNA_position LoF       LoF_flag LoF_filter  AC  \
# 174506       ENST00000378609           379  HC            NaN        NaN   1
# 190838       ENST00000378585           124  HC  PHYLOCSF_WEAK        NaN   1
# 191152       ENST00000378585           172  HC            NaN        NaN   1
# 191153       ENST00000378585           172  HC            NaN        NaN   1
# 191172       ENST00000378585           199  HC            NaN        NaN   1
# ...                      ...           ...  ..            ...        ...  ..
# 1613988      ENST00000262795          2595  HC            NaN        NaN   1
# 1614099      ENST00000262795          2697  HC            NaN        NaN   1
# 1614606      ENST00000262795          3157  HC            NaN        NaN   1
# 1614829      ENST00000262795          3394  HC            NaN        NaN   1
# 1615796      ENST00000262795          4633  HC            NaN        NaN   1
#
#          LOEUF      pext NMD_escape
# 174506   0.145  0.966547         NO
# 190838   0.245  1.000000         NO
# 191152   0.245  1.000000         NO
# 191153   0.245  1.000000         NO
# 191172   0.245  1.000000         NO
# ...        ...       ...        ...
# 1613988  0.123  1.000000         NO
# 1614099  0.123  1.000000         NO
# 1614606  0.123  1.000000         NO
# 1614829  0.123  1.000000         NO
# 1615796  0.123  1.000000         NO
#
# [10749 rows x 17 columns]

# %% [markdown]
# **Условно доброкачественные**:

# %%
ben_nmd = nmd_df.query('AC >= 2')
ben_nmd
# Out:
#          CHROM       POS          rsID REF ALT Impact  Consequence  \
# 191650    chr1   2025660             .   C   A   HIGH  stop_gained
# 192501    chr1   2028164  rs1441225021   C   G   HIGH  stop_gained
# 193029    chr1   2029236  rs1405824159   C   T   HIGH  stop_gained
# 207717    chr1   2228818  rs1225111926   C   T   HIGH  stop_gained
# 236246    chr1   2511342             .   A   C   HIGH  stop_gained
# ...        ...       ...           ...  ..  ..    ...          ...
# 1601315  chr22  50600868             .   C   A   HIGH  stop_gained
# 1613853  chr22  50720238             .   C   A   HIGH  stop_gained
# 1614179  chr22  50720534             .   G   T   HIGH  stop_gained
# 1615180  chr22  50721521             .   G   T   HIGH  stop_gained
# 1615531  chr22  50721995             .   G   T   HIGH  stop_gained
#
#         Gene_symbol Canonical_transcript cDNA_position LoF LoF_flag  \
# 191650        GABRD      ENST00000378585           471  HC      NaN
# 192501        GABRD      ENST00000378585           642  HC      NaN
# 193029        GABRD      ENST00000378585           896  HC      NaN
# 207717          SKI      ENST00000378536           500  HC      NaN
# 236246        PANK4      ENST00000378466          1838  HC      NaN
# ...             ...                  ...           ...  ..      ...
# 1601315    MAPK8IP2      ENST00000329492            76  HC      NaN
# 1613853      SHANK3      ENST00000262795          2456  HC      NaN
# 1614179      SHANK3      ENST00000262795          2752  HC      NaN
# 1615180      SHANK3      ENST00000262795          3739  HC      NaN
# 1615531      SHANK3      ENST00000262795          4213  HC      NaN
#
#         LoF_filter  AC  LOEUF      pext NMD_escape
# 191650         NaN   2  0.245  1.000000         NO
# 192501         NaN   3  0.245  1.000000         NO
# 193029         NaN   5  0.245  1.000000         NO
# 207717         NaN   2  0.194  0.950938         NO
# 236246         NaN   2  0.304  0.694764         NO
# ...            ...  ..    ...       ...        ...
# 1601315        NaN   2  0.100  0.775794         NO
# 1613853        NaN   3  0.123  1.000000         NO
# 1614179        NaN   2  0.123  1.000000         NO
# 1615180        NaN   5  0.123  1.000000         NO
# 1615531        NaN   2  0.123  1.000000         NO
#
# [3594 rows x 17 columns]

# %% [markdown]
# #### Обработка датафрейма Clinvar

# %%
clinvar_df = pd.read_table('data_dir/clinvar/clinvar_20240331_anno.vcf.tsv')

# %%
clinvar_df
# Out:
#                       CHROM     POS       ID REF ALT                  CLNSIG  \
# 0                      chr1   69134  2205837   A   G           Likely_benign
# 1                      chr1   69581  2252161   C   G  Uncertain_significance
# 2                      chr1   69682  2396347   G   A  Uncertain_significance
# 3                      chr1   69769  2288999   T   C  Uncertain_significance
# 4                      chr1   69995  2351346   G   C  Uncertain_significance
# ...                     ...     ...      ...  ..  ..                     ...
# 34840143     chrNT_187693.1  273806  2219599   G   A           Likely_benign
# 34840144     chrNT_187693.1  273866  2237818   A   C  Uncertain_significance
# 34840145     chrNT_187693.1  274366  2206666   G   C  Uncertain_significance
# 34840146     chrNT_187693.1  275068  2241971   T   C  Uncertain_significance
# 34840147  chrNW_009646201.1   83614    17735  TC   T                  Benign
#
#                               CLNVC                             GENEINFO  \
# 0         single_nucleotide_variant                          OR4F5:79501
# 1         single_nucleotide_variant                          OR4F5:79501
# 2         single_nucleotide_variant                          OR4F5:79501
# 3         single_nucleotide_variant                          OR4F5:79501
# 4         single_nucleotide_variant                          OR4F5:79501
# ...                             ...                                  ...
# 34840143  single_nucleotide_variant                         LILRA3:11026
# 34840144  single_nucleotide_variant                         LILRA3:11026
# 34840145  single_nucleotide_variant                         LILRA3:11026
# 34840146  single_nucleotide_variant  LILRA3:11026|LOC126057115:126057115
# 34840147                   Deletion                               ABO:28
#
#                                      MC         Consequence SYMBOL  \
# 0           SO:0001583|missense_variant    missense_variant  OR4F5
# 1           SO:0001583|missense_variant    missense_variant  OR4F5
# 2           SO:0001583|missense_variant    missense_variant  OR4F5
# 3           SO:0001583|missense_variant    missense_variant  OR4F5
# 4           SO:0001583|missense_variant    missense_variant  OR4F5
# ...                                 ...                 ...    ...
# 34840143    SO:0001583|missense_variant  intergenic_variant    NaN
# 34840144    SO:0001583|missense_variant  intergenic_variant    NaN
# 34840145    SO:0001583|missense_variant  intergenic_variant    NaN
# 34840146    SO:0001583|missense_variant  intergenic_variant    NaN
# 34840147  SO:0001589|frameshift_variant  intergenic_variant    NaN
#
#                      Gene Feature_type          Feature         BIOTYPE  \
# 0         ENSG00000186092   Transcript  ENST00000641515  protein_coding
# 1         ENSG00000186092   Transcript  ENST00000641515  protein_coding
# 2         ENSG00000186092   Transcript  ENST00000641515  protein_coding
# 3         ENSG00000186092   Transcript  ENST00000641515  protein_coding
# 4         ENSG00000186092   Transcript  ENST00000641515  protein_coding
# ...                   ...          ...              ...             ...
# 34840143              NaN          NaN              NaN             NaN
# 34840144              NaN          NaN              NaN             NaN
# 34840145              NaN          NaN              NaN             NaN
# 34840146              NaN          NaN              NaN             NaN
# 34840147              NaN          NaN              NaN             NaN
#
#          cDNA_position CANONICAL
# 0                  167       YES
# 1                  614       YES
# 2                  715       YES
# 3                  802       YES
# 4                 1028       YES
# ...                ...       ...
# 34840143           NaN       NaN
# 34840144           NaN       NaN
# 34840145           NaN       NaN
# 34840146           NaN       NaN
# 34840147           NaN       NaN
#
# [34840148 rows x 17 columns]

# %% [markdown]
# Добавляем вариантам значение LOEUF и отбираем только условно высококонсервативные варианты:

# %%
clinvar_df.loc[:, 'LOEUF'] = clinvar_df['Feature'].map(loeuf_by_transcript_dict)

# %%
clinvar_df = clinvar_df.query('LOEUF < 0.35')

# %% [markdown]
# Добавляем метрику pext и отбираем только более экспрессирующиеся варианты:

# %%
for index, row in clinvar_df.iterrows():
    key = (row['CHROM'], row['POS'], row['REF'], row['ALT'])
    
    if key in pext_dict:
        clinvar_df.loc[index, 'pext'] = pext_dict[key]
    else:
        clinvar_df.loc[index, 'pext'] = None
# Out:
# /tmp/ipykernel_3118914/3120561689.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinvar_df.loc[index, 'pext'] = None

# %%
clinvar_df['pext'].notna().sum()
# Out:
# 15299

# %%
clinvar_df['pext'] = clinvar_df['pext'].astype(float)
clinvar_df = clinvar_df[clinvar_df['pext'] > 0.5]
# Out:
# /tmp/ipykernel_3118914/3569552487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinvar_df['pext'] = clinvar_df['pext'].astype(float)

# %%
clinvar_df['pext'].notna().sum()
# Out:
# 10454

# %% [markdown]
# Оставим только варианты на каноническом транскрипте:

# %%
clinvar_canon_df = clinvar_df[clinvar_df['CANONICAL'] == 'YES']

# %% [markdown]
# Оставим только аутосомы:

# %%
clinvar_canon_df['CHROM'].unique()
# Out:
# array(['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8',
#        'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15',
#        'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22'],
#       dtype=object)

# %%
clinvar_canon_df = clinvar_canon_df[~clinvar_canon_df['CHROM'].isin(['chrMT', 'chrX', 'chrY', 'chrNT_113889.1'])]

# %%
clinvar_canon_df['CHROM'].unique()
# Out:
# array(['chr1', 'chr2', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8',
#        'chr9', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15',
#        'chr16', 'chr17', 'chr18', 'chr19', 'chr20', 'chr21', 'chr22'],
#       dtype=object)

# %% [markdown]
# Уберём строки, в которых нет информации о транскрипте или позиции кДНК:

# %%
clinvar_canon_df = clinvar_canon_df.dropna(subset=['cDNA_position', 'Feature'])

# %% [markdown]
# Оставим только однонуклеотидные варианты:

# %%
clinvar_canon_df = clinvar_canon_df[~clinvar_canon_df['cDNA_position'].str.contains('-')]

# %% [markdown]
# Посмотрим, какие классы по клинической значимости у нас встречаются.

# %%
# clinvar_canon_df[clinvar_canon_df['CLNSIG'].str.contains('pathogenic', case=False, na=False)]['CLNSIG'].unique()

# %%
# clinvar_canon_df['Consequence'].unique()

# %%
# clinvar_canon_df['MC'].unique()

# %% [markdown]
# Оставим только стопгейны (в Clinvar - nonsense), отмеченные как пат/лпат.

# %%
clinvar_canon_df['CLNSIG'].isnull().sum()
# Out:
# 0

# %%
# удаляем затесавшуюся строку с пустым значением CLNSIG
clinvar_canon_df = clinvar_canon_df.dropna(subset=['CLNSIG'])

# %%
# оставляем пат/лпат нонсенсы
clinvar_final_pat = clinvar_canon_df[
    clinvar_canon_df['CLNSIG'].str.contains('pathogenic') &
    ~clinvar_canon_df['CLNSIG'].str.contains('pathogenicity') &
    clinvar_canon_df['MC'].str.contains('nonsense') &
    clinvar_canon_df['Consequence'].str.contains('stop_gained')
]

clinvar_final_pat
# Out:
#           CHROM       POS       ID REF ALT                        CLNSIG  \
# 102377     chr1   3412331  3062115   C   T             Likely_pathogenic
# 104819     chr1   3426212  1805269   C   T             Likely_pathogenic
# 107720     chr1   3722204  1192322   G   T  Pathogenic/Likely_pathogenic
# 131443     chr1   6124075  2444409   G   T             Likely_pathogenic
# 131598     chr1   6126662  2691722   G   A             Likely_pathogenic
# ...         ...       ...      ...  ..  ..                           ...
# 33497124  chr22  50722235   422407   C   T  Pathogenic/Likely_pathogenic
# 33497214  chr22  50722340  1177294   C   T             Likely_pathogenic
# 33497434  chr22  50730878  3024516   G   T             Likely_pathogenic
# 33497518  chr22  50730977   427096   A   T             Likely_pathogenic
# 33497658  chr22  50731088   988471   C   T  Pathogenic/Likely_pathogenic
#
#                               CLNVC      GENEINFO                   MC  \
# 102377    single_nucleotide_variant  PRDM16:63976  SO:0001587|nonsense
# 104819    single_nucleotide_variant  PRDM16:63976  SO:0001587|nonsense
# 107720    single_nucleotide_variant     TP73:7161  SO:0001587|nonsense
# 131443    single_nucleotide_variant    CHD5:26038  SO:0001587|nonsense
# 131598    single_nucleotide_variant    CHD5:26038  SO:0001587|nonsense
# ...                             ...           ...                  ...
# 33497124  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33497214  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33497434  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33497518  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33497658  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
#
#           Consequence  SYMBOL             Gene Feature_type          Feature  \
# 102377    stop_gained  PRDM16  ENSG00000142611   Transcript  ENST00000270722
# 104819    stop_gained  PRDM16  ENSG00000142611   Transcript  ENST00000270722
# 107720    stop_gained    TP73  ENSG00000078900   Transcript  ENST00000378295
# 131443    stop_gained    CHD5  ENSG00000116254   Transcript  ENST00000262450
# 131598    stop_gained    CHD5  ENSG00000116254   Transcript  ENST00000262450
# ...               ...     ...              ...          ...              ...
# 33497124  stop_gained  SHANK3  ENSG00000251322   Transcript  ENST00000262795
# 33497214  stop_gained  SHANK3  ENSG00000251322   Transcript  ENST00000262795
# 33497434  stop_gained  SHANK3  ENSG00000251322   Transcript  ENST00000262795
# 33497518  stop_gained  SHANK3  ENSG00000251322   Transcript  ENST00000262795
# 33497658  stop_gained  SHANK3  ENSG00000251322   Transcript  ENST00000262795
#
#                  BIOTYPE cDNA_position CANONICAL  LOEUF      pext
# 102377    protein_coding          2191       YES  0.187  0.848889
# 104819    protein_coding          3328       YES  0.187  0.848889
# 107720    protein_coding           772       YES  0.256  0.956129
# 131443    protein_coding          4870       YES  0.157  0.928222
# 131598    protein_coding          4286       YES  0.157  0.928222
# ...                  ...           ...       ...    ...       ...
# 33497124  protein_coding          4453       YES  0.123  1.000000
# 33497214  protein_coding          4558       YES  0.123  1.000000
# 33497434  protein_coding          4840       YES  0.123  1.000000
# 33497518  protein_coding          4939       YES  0.123  1.000000
# 33497658  protein_coding          5050       YES  0.123  1.000000
#
# [1184 rows x 19 columns]

# %%
clinvar_final_pat['CLNSIG'].unique()
# Out:
# array(['Likely_pathogenic', 'Pathogenic/Likely_pathogenic'], dtype=object)

# %% [markdown]
# Расставим NMD(+) и NMD(-) и разделим датафреймы:

# %%
mask_transcript = clinvar_final_pat['Feature'].isin(nmd_bed_df['transcript'].str.split('.').str[0])
clinvar_final_pat.loc[~mask_transcript, 'NMD_escape'] = 'NO_TRANSCRIPT'

for index, row in nmd_bed_df.iterrows():
    transcript_split = row['transcript'].split('.')[0]
    
    mask_all = (clinvar_final_pat['Feature'] == transcript_split) & \
             (clinvar_final_pat['POS'] >= row['start']) & \
             (clinvar_final_pat['POS'] <= row['end'])
    
    clinvar_final_pat.loc[mask_all, 'NMD_escape'] = 'YES'


clinvar_final_pat.loc[(clinvar_final_pat['NMD_escape'] != 'YES') & (clinvar_final_pat['NMD_escape'] != 'NO_TRANSCRIPT'), 'NMD_escape'] = 'NO'
# Out:
# /tmp/ipykernel_3118914/84413560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clinvar_final_pat.loc[~mask_transcript, 'NMD_escape'] = 'NO_TRANSCRIPT'

# %%
clinvar_nmd_counts = clinvar_final_pat['NMD_escape'].value_counts()

plt.figure(figsize=(5, 5))
plt.pie(clinvar_nmd_counts, 
        labels=clinvar_nmd_counts.index, 
        autopct='%1.1f%%', 
        startangle=140,
        colors=sns.color_palette("Spectral")) 
plt.axis('equal')
plt.show()

# %% [markdown]
# Сделаем отдельные датафреймы для NMD(+) и NMD(-):

# %%
clinvar_nmd_esc_df = clinvar_final_pat[clinvar_final_pat['NMD_escape'] == 'YES']
clinvar_nmd_df = clinvar_final_pat[clinvar_final_pat['NMD_escape'] == 'NO']

# %% [markdown]
# #### Убираем из условно доброкачественных вариантов все паты Clinvar

# %% [markdown]
# Теперь пересечём `clinvar_nmd_df` и `ben_nmd` и оставим в последнем только те варианты, которых нет в `clinvar_nmd_df`.

# %% [markdown]
# Соединим два датафрейма, удалим все пересечения по `'CHROM'`, `'POS'`, `'REF'`, `'ALT'`, и затем удалим остатки `clinvar_nmd_df` (т.е. удалим все строки, у которых не пусто в столбце `CLNSIG`).

# %%
clinvar_nmd = clinvar_nmd_df.rename(columns={'Feature': 'Canonical_transcript'})

# %%
merged_clinvar_and_ben = pd.concat([ben_nmd, clinvar_nmd], ignore_index=True)
merged_clinvar_and_ben
# Out:
#       CHROM       POS          rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1   2025660             .   C   A   HIGH  stop_gained       GABRD
# 1      chr1   2028164  rs1441225021   C   G   HIGH  stop_gained       GABRD
# 2      chr1   2029236  rs1405824159   C   T   HIGH  stop_gained       GABRD
# 3      chr1   2228818  rs1225111926   C   T   HIGH  stop_gained         SKI
# 4      chr1   2511342             .   A   C   HIGH  stop_gained       PANK4
# ...     ...       ...           ...  ..  ..    ...          ...         ...
# 4524  chr22  50447442           NaN   G   C    NaN  stop_gained         NaN
# 4525  chr22  50698763           NaN   C   A    NaN  stop_gained         NaN
# 4526  chr22  50721176           NaN   C   T    NaN  stop_gained         NaN
# 4527  chr22  50722235           NaN   C   T    NaN  stop_gained         NaN
# 4528  chr22  50722340           NaN   C   T    NaN  stop_gained         NaN
#
#      Canonical_transcript cDNA_position  ...         ID  \
# 0         ENST00000378585           471  ...        NaN
# 1         ENST00000378585           642  ...        NaN
# 2         ENST00000378585           896  ...        NaN
# 3         ENST00000378536           500  ...        NaN
# 4         ENST00000378466          1838  ...        NaN
# ...                   ...           ...  ...        ...
# 4524      ENST00000380817          5658  ...  1301645.0
# 4525      ENST00000262795          1623  ...   812791.0
# 4526      ENST00000262795          3394  ...  2442348.0
# 4527      ENST00000262795          4453  ...   422407.0
# 4528      ENST00000262795          4558  ...  1177294.0
#
#                             CLNSIG                      CLNVC      GENEINFO  \
# 0                              NaN                        NaN           NaN
# 1                              NaN                        NaN           NaN
# 2                              NaN                        NaN           NaN
# 3                              NaN                        NaN           NaN
# 4                              NaN                        NaN           NaN
# ...                            ...                        ...           ...
# 4524             Likely_pathogenic  single_nucleotide_variant     SBF1:6305
# 4525             Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
# 4526             Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
# 4527  Pathogenic/Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
# 4528             Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
#
#                        MC  SYMBOL             Gene  Feature_type  \
# 0                     NaN     NaN              NaN           NaN
# 1                     NaN     NaN              NaN           NaN
# 2                     NaN     NaN              NaN           NaN
# 3                     NaN     NaN              NaN           NaN
# 4                     NaN     NaN              NaN           NaN
# ...                   ...     ...              ...           ...
# 4524  SO:0001587|nonsense    SBF1  ENSG00000100241    Transcript
# 4525  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
# 4526  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
# 4527  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
# 4528  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
#
#              BIOTYPE CANONICAL
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
# ...              ...       ...
# 4524  protein_coding       YES
# 4525  protein_coding       YES
# 4526  protein_coding       YES
# 4527  protein_coding       YES
# 4528  protein_coding       YES
#
# [4529 rows x 27 columns]

# %%
# убираем дубликаты (если есть)
ben_nmd_filtered = merged_clinvar_and_ben.drop_duplicates(subset=['CHROM', 'POS', 'REF', 'ALT'], keep=False)
ben_nmd_filtered
# Out:
#       CHROM       POS          rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1   2025660             .   C   A   HIGH  stop_gained       GABRD
# 1      chr1   2028164  rs1441225021   C   G   HIGH  stop_gained       GABRD
# 2      chr1   2029236  rs1405824159   C   T   HIGH  stop_gained       GABRD
# 3      chr1   2228818  rs1225111926   C   T   HIGH  stop_gained         SKI
# 4      chr1   2511342             .   A   C   HIGH  stop_gained       PANK4
# ...     ...       ...           ...  ..  ..    ...          ...         ...
# 4524  chr22  50447442           NaN   G   C    NaN  stop_gained         NaN
# 4525  chr22  50698763           NaN   C   A    NaN  stop_gained         NaN
# 4526  chr22  50721176           NaN   C   T    NaN  stop_gained         NaN
# 4527  chr22  50722235           NaN   C   T    NaN  stop_gained         NaN
# 4528  chr22  50722340           NaN   C   T    NaN  stop_gained         NaN
#
#      Canonical_transcript cDNA_position  ...         ID  \
# 0         ENST00000378585           471  ...        NaN
# 1         ENST00000378585           642  ...        NaN
# 2         ENST00000378585           896  ...        NaN
# 3         ENST00000378536           500  ...        NaN
# 4         ENST00000378466          1838  ...        NaN
# ...                   ...           ...  ...        ...
# 4524      ENST00000380817          5658  ...  1301645.0
# 4525      ENST00000262795          1623  ...   812791.0
# 4526      ENST00000262795          3394  ...  2442348.0
# 4527      ENST00000262795          4453  ...   422407.0
# 4528      ENST00000262795          4558  ...  1177294.0
#
#                             CLNSIG                      CLNVC      GENEINFO  \
# 0                              NaN                        NaN           NaN
# 1                              NaN                        NaN           NaN
# 2                              NaN                        NaN           NaN
# 3                              NaN                        NaN           NaN
# 4                              NaN                        NaN           NaN
# ...                            ...                        ...           ...
# 4524             Likely_pathogenic  single_nucleotide_variant     SBF1:6305
# 4525             Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
# 4526             Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
# 4527  Pathogenic/Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
# 4528             Likely_pathogenic  single_nucleotide_variant  SHANK3:85358
#
#                        MC  SYMBOL             Gene  Feature_type  \
# 0                     NaN     NaN              NaN           NaN
# 1                     NaN     NaN              NaN           NaN
# 2                     NaN     NaN              NaN           NaN
# 3                     NaN     NaN              NaN           NaN
# 4                     NaN     NaN              NaN           NaN
# ...                   ...     ...              ...           ...
# 4524  SO:0001587|nonsense    SBF1  ENSG00000100241    Transcript
# 4525  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
# 4526  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
# 4527  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
# 4528  SO:0001587|nonsense  SHANK3  ENSG00000251322    Transcript
#
#              BIOTYPE CANONICAL
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
# ...              ...       ...
# 4524  protein_coding       YES
# 4525  protein_coding       YES
# 4526  protein_coding       YES
# 4527  protein_coding       YES
# 4528  protein_coding       YES
#
# [4421 rows x 27 columns]

# %%
# убираем остатки клинвара
ben_nmd_filtered = ben_nmd_filtered[~ben_nmd_filtered['CLNSIG'].notna()]
ben_nmd_filtered
# Out:
#       CHROM       POS          rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1   2025660             .   C   A   HIGH  stop_gained       GABRD
# 1      chr1   2028164  rs1441225021   C   G   HIGH  stop_gained       GABRD
# 2      chr1   2029236  rs1405824159   C   T   HIGH  stop_gained       GABRD
# 3      chr1   2228818  rs1225111926   C   T   HIGH  stop_gained         SKI
# 4      chr1   2511342             .   A   C   HIGH  stop_gained       PANK4
# ...     ...       ...           ...  ..  ..    ...          ...         ...
# 3589  chr22  50600868             .   C   A   HIGH  stop_gained    MAPK8IP2
# 3590  chr22  50720238             .   C   A   HIGH  stop_gained      SHANK3
# 3591  chr22  50720534             .   G   T   HIGH  stop_gained      SHANK3
# 3592  chr22  50721521             .   G   T   HIGH  stop_gained      SHANK3
# 3593  chr22  50721995             .   G   T   HIGH  stop_gained      SHANK3
#
#      Canonical_transcript cDNA_position  ...  ID CLNSIG CLNVC  GENEINFO   MC  \
# 0         ENST00000378585           471  ... NaN    NaN   NaN       NaN  NaN
# 1         ENST00000378585           642  ... NaN    NaN   NaN       NaN  NaN
# 2         ENST00000378585           896  ... NaN    NaN   NaN       NaN  NaN
# 3         ENST00000378536           500  ... NaN    NaN   NaN       NaN  NaN
# 4         ENST00000378466          1838  ... NaN    NaN   NaN       NaN  NaN
# ...                   ...           ...  ...  ..    ...   ...       ...  ...
# 3589      ENST00000329492            76  ... NaN    NaN   NaN       NaN  NaN
# 3590      ENST00000262795          2456  ... NaN    NaN   NaN       NaN  NaN
# 3591      ENST00000262795          2752  ... NaN    NaN   NaN       NaN  NaN
# 3592      ENST00000262795          3739  ... NaN    NaN   NaN       NaN  NaN
# 3593      ENST00000262795          4213  ... NaN    NaN   NaN       NaN  NaN
#
#       SYMBOL Gene  Feature_type BIOTYPE CANONICAL
# 0        NaN  NaN           NaN     NaN       NaN
# 1        NaN  NaN           NaN     NaN       NaN
# 2        NaN  NaN           NaN     NaN       NaN
# 3        NaN  NaN           NaN     NaN       NaN
# 4        NaN  NaN           NaN     NaN       NaN
# ...      ...  ...           ...     ...       ...
# 3589     NaN  NaN           NaN     NaN       NaN
# 3590     NaN  NaN           NaN     NaN       NaN
# 3591     NaN  NaN           NaN     NaN       NaN
# 3592     NaN  NaN           NaN     NaN       NaN
# 3593     NaN  NaN           NaN     NaN       NaN
#
# [3540 rows x 27 columns]

# %%
ben_nmd_filtered.columns
# Out:
# Index(['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Impact', 'Consequence',
#        'Gene_symbol', 'Canonical_transcript', 'cDNA_position', 'LoF',
#        'LoF_flag', 'LoF_filter', 'AC', 'LOEUF', 'pext', 'NMD_escape', 'ID',
#        'CLNSIG', 'CLNVC', 'GENEINFO', 'MC', 'SYMBOL', 'Gene', 'Feature_type',
#        'BIOTYPE', 'CANONICAL'],
#       dtype='object')

# %% [markdown]
# Убираем ненужны столбцы, оставшиеся после Клинвара.

# %%
ben_nmd_filtered = ben_nmd_filtered.drop(columns=['ID', 'CLNSIG', 'CLNVC', 'GENEINFO', 'MC', 'SYMBOL', 
                                                'Gene', 'Feature_type', 'BIOTYPE', 'CANONICAL'])
ben_nmd_filtered
# Out:
#       CHROM       POS          rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1   2025660             .   C   A   HIGH  stop_gained       GABRD
# 1      chr1   2028164  rs1441225021   C   G   HIGH  stop_gained       GABRD
# 2      chr1   2029236  rs1405824159   C   T   HIGH  stop_gained       GABRD
# 3      chr1   2228818  rs1225111926   C   T   HIGH  stop_gained         SKI
# 4      chr1   2511342             .   A   C   HIGH  stop_gained       PANK4
# ...     ...       ...           ...  ..  ..    ...          ...         ...
# 3589  chr22  50600868             .   C   A   HIGH  stop_gained    MAPK8IP2
# 3590  chr22  50720238             .   C   A   HIGH  stop_gained      SHANK3
# 3591  chr22  50720534             .   G   T   HIGH  stop_gained      SHANK3
# 3592  chr22  50721521             .   G   T   HIGH  stop_gained      SHANK3
# 3593  chr22  50721995             .   G   T   HIGH  stop_gained      SHANK3
#
#      Canonical_transcript cDNA_position LoF LoF_flag LoF_filter   AC  LOEUF  \
# 0         ENST00000378585           471  HC      NaN        NaN  2.0  0.245
# 1         ENST00000378585           642  HC      NaN        NaN  3.0  0.245
# 2         ENST00000378585           896  HC      NaN        NaN  5.0  0.245
# 3         ENST00000378536           500  HC      NaN        NaN  2.0  0.194
# 4         ENST00000378466          1838  HC      NaN        NaN  2.0  0.304
# ...                   ...           ...  ..      ...        ...  ...    ...
# 3589      ENST00000329492            76  HC      NaN        NaN  2.0  0.100
# 3590      ENST00000262795          2456  HC      NaN        NaN  3.0  0.123
# 3591      ENST00000262795          2752  HC      NaN        NaN  2.0  0.123
# 3592      ENST00000262795          3739  HC      NaN        NaN  5.0  0.123
# 3593      ENST00000262795          4213  HC      NaN        NaN  2.0  0.123
#
#           pext NMD_escape
# 0     1.000000         NO
# 1     1.000000         NO
# 2     1.000000         NO
# 3     0.950938         NO
# 4     0.694764         NO
# ...        ...        ...
# 3589  0.775794         NO
# 3590  1.000000         NO
# 3591  1.000000         NO
# 3592  1.000000         NO
# 3593  1.000000         NO
#
# [3540 rows x 17 columns]

# %% [markdown]
# Было вот так до фильтрации:

# %%
ben_nmd.shape
# Out:
# (3594, 17)

# %% [markdown]
# Добавим позицию в кодоне:

# %%
rows_to_remove = ben_nmd_filtered[ben_nmd_filtered['cDNA_position'].str.contains("-")].index
ben_nmd_filtered = ben_nmd_filtered.drop(rows_to_remove)

ben_nmd_filtered['cDNA_position'] = ben_nmd_filtered['cDNA_position'].astype(int)

ben_nmd_filtered['Codon_position'] = np.where(ben_nmd_filtered['cDNA_position'] % 3 == 1, 1,
                                           np.where(ben_nmd_filtered['cDNA_position'] % 3 == 2, 2, 
                                                    3))

ben_nmd_filtered
# Out:
#       CHROM       POS          rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1   2025660             .   C   A   HIGH  stop_gained       GABRD
# 1      chr1   2028164  rs1441225021   C   G   HIGH  stop_gained       GABRD
# 2      chr1   2029236  rs1405824159   C   T   HIGH  stop_gained       GABRD
# 3      chr1   2228818  rs1225111926   C   T   HIGH  stop_gained         SKI
# 4      chr1   2511342             .   A   C   HIGH  stop_gained       PANK4
# ...     ...       ...           ...  ..  ..    ...          ...         ...
# 3589  chr22  50600868             .   C   A   HIGH  stop_gained    MAPK8IP2
# 3590  chr22  50720238             .   C   A   HIGH  stop_gained      SHANK3
# 3591  chr22  50720534             .   G   T   HIGH  stop_gained      SHANK3
# 3592  chr22  50721521             .   G   T   HIGH  stop_gained      SHANK3
# 3593  chr22  50721995             .   G   T   HIGH  stop_gained      SHANK3
#
#      Canonical_transcript  cDNA_position LoF LoF_flag LoF_filter   AC  LOEUF  \
# 0         ENST00000378585            471  HC      NaN        NaN  2.0  0.245
# 1         ENST00000378585            642  HC      NaN        NaN  3.0  0.245
# 2         ENST00000378585            896  HC      NaN        NaN  5.0  0.245
# 3         ENST00000378536            500  HC      NaN        NaN  2.0  0.194
# 4         ENST00000378466           1838  HC      NaN        NaN  2.0  0.304
# ...                   ...            ...  ..      ...        ...  ...    ...
# 3589      ENST00000329492             76  HC      NaN        NaN  2.0  0.100
# 3590      ENST00000262795           2456  HC      NaN        NaN  3.0  0.123
# 3591      ENST00000262795           2752  HC      NaN        NaN  2.0  0.123
# 3592      ENST00000262795           3739  HC      NaN        NaN  5.0  0.123
# 3593      ENST00000262795           4213  HC      NaN        NaN  2.0  0.123
#
#           pext NMD_escape  Codon_position
# 0     1.000000         NO               3
# 1     1.000000         NO               3
# 2     1.000000         NO               2
# 3     0.950938         NO               2
# 4     0.694764         NO               2
# ...        ...        ...             ...
# 3589  0.775794         NO               1
# 3590  1.000000         NO               2
# 3591  1.000000         NO               1
# 3592  1.000000         NO               1
# 3593  1.000000         NO               1
#
# [3540 rows x 18 columns]

# %% [markdown]
# **Датафрейм с условно доброкачественными вариантами готов.**

# %% [markdown]
# #### Добавляем в условно патогенные варианты все непопуляционные паты Clinvar

# %% [markdown]
# Теперь добавим в `pat_nmd` варианты, которые являются пат/лпат по ClinVar и при этом не встречаются в базе GnomAD v4.

# %%
pat_nmd
# Out:
#          CHROM       POS         rsID REF ALT Impact  Consequence Gene_symbol  \
# 174506    chr1   1825438  rs867938404   G   A   HIGH  stop_gained        GNB1
# 190838    chr1   2019468            .   C   A   HIGH  stop_gained       GABRD
# 191152    chr1   2024966            .   C   A   HIGH  stop_gained       GABRD
# 191153    chr1   2024966            .   C   G   HIGH  stop_gained       GABRD
# 191172    chr1   2024993            .   G   A   HIGH  stop_gained       GABRD
# ...        ...       ...          ...  ..  ..    ...          ...         ...
# 1613988  chr22  50720377            .   C   A   HIGH  stop_gained      SHANK3
# 1614099  chr22  50720479            .   T   A   HIGH  stop_gained      SHANK3
# 1614606  chr22  50720939            .   G   T   HIGH  stop_gained      SHANK3
# 1614829  chr22  50721176            .   C   T   HIGH  stop_gained      SHANK3
# 1615796  chr22  50722415            .   A   T   HIGH  stop_gained      SHANK3
#
#         Canonical_transcript cDNA_position LoF       LoF_flag LoF_filter  AC  \
# 174506       ENST00000378609           379  HC            NaN        NaN   1
# 190838       ENST00000378585           124  HC  PHYLOCSF_WEAK        NaN   1
# 191152       ENST00000378585           172  HC            NaN        NaN   1
# 191153       ENST00000378585           172  HC            NaN        NaN   1
# 191172       ENST00000378585           199  HC            NaN        NaN   1
# ...                      ...           ...  ..            ...        ...  ..
# 1613988      ENST00000262795          2595  HC            NaN        NaN   1
# 1614099      ENST00000262795          2697  HC            NaN        NaN   1
# 1614606      ENST00000262795          3157  HC            NaN        NaN   1
# 1614829      ENST00000262795          3394  HC            NaN        NaN   1
# 1615796      ENST00000262795          4633  HC            NaN        NaN   1
#
#          LOEUF      pext NMD_escape
# 174506   0.145  0.966547         NO
# 190838   0.245  1.000000         NO
# 191152   0.245  1.000000         NO
# 191153   0.245  1.000000         NO
# 191172   0.245  1.000000         NO
# ...        ...       ...        ...
# 1613988  0.123  1.000000         NO
# 1614099  0.123  1.000000         NO
# 1614606  0.123  1.000000         NO
# 1614829  0.123  1.000000         NO
# 1615796  0.123  1.000000         NO
#
# [10749 rows x 17 columns]

# %%
clinvar_nmd
# Out:
#           CHROM       POS       ID REF ALT                        CLNSIG  \
# 102377     chr1   3412331  3062115   C   T             Likely_pathogenic
# 104819     chr1   3426212  1805269   C   T             Likely_pathogenic
# 107720     chr1   3722204  1192322   G   T  Pathogenic/Likely_pathogenic
# 131443     chr1   6124075  2444409   G   T             Likely_pathogenic
# 131598     chr1   6126662  2691722   G   A             Likely_pathogenic
# ...         ...       ...      ...  ..  ..                           ...
# 33343503  chr22  50447442  1301645   G   C             Likely_pathogenic
# 33494384  chr22  50698763   812791   C   A             Likely_pathogenic
# 33496274  chr22  50721176  2442348   C   T             Likely_pathogenic
# 33497124  chr22  50722235   422407   C   T  Pathogenic/Likely_pathogenic
# 33497214  chr22  50722340  1177294   C   T             Likely_pathogenic
#
#                               CLNVC      GENEINFO                   MC  \
# 102377    single_nucleotide_variant  PRDM16:63976  SO:0001587|nonsense
# 104819    single_nucleotide_variant  PRDM16:63976  SO:0001587|nonsense
# 107720    single_nucleotide_variant     TP73:7161  SO:0001587|nonsense
# 131443    single_nucleotide_variant    CHD5:26038  SO:0001587|nonsense
# 131598    single_nucleotide_variant    CHD5:26038  SO:0001587|nonsense
# ...                             ...           ...                  ...
# 33343503  single_nucleotide_variant     SBF1:6305  SO:0001587|nonsense
# 33494384  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33496274  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33497124  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
# 33497214  single_nucleotide_variant  SHANK3:85358  SO:0001587|nonsense
#
#           Consequence  SYMBOL             Gene Feature_type  \
# 102377    stop_gained  PRDM16  ENSG00000142611   Transcript
# 104819    stop_gained  PRDM16  ENSG00000142611   Transcript
# 107720    stop_gained    TP73  ENSG00000078900   Transcript
# 131443    stop_gained    CHD5  ENSG00000116254   Transcript
# 131598    stop_gained    CHD5  ENSG00000116254   Transcript
# ...               ...     ...              ...          ...
# 33343503  stop_gained    SBF1  ENSG00000100241   Transcript
# 33494384  stop_gained  SHANK3  ENSG00000251322   Transcript
# 33496274  stop_gained  SHANK3  ENSG00000251322   Transcript
# 33497124  stop_gained  SHANK3  ENSG00000251322   Transcript
# 33497214  stop_gained  SHANK3  ENSG00000251322   Transcript
#
#          Canonical_transcript         BIOTYPE cDNA_position CANONICAL  LOEUF  \
# 102377        ENST00000270722  protein_coding          2191       YES  0.187
# 104819        ENST00000270722  protein_coding          3328       YES  0.187
# 107720        ENST00000378295  protein_coding           772       YES  0.256
# 131443        ENST00000262450  protein_coding          4870       YES  0.157
# 131598        ENST00000262450  protein_coding          4286       YES  0.157
# ...                       ...             ...           ...       ...    ...
# 33343503      ENST00000380817  protein_coding          5658       YES  0.265
# 33494384      ENST00000262795  protein_coding          1623       YES  0.123
# 33496274      ENST00000262795  protein_coding          3394       YES  0.123
# 33497124      ENST00000262795  protein_coding          4453       YES  0.123
# 33497214      ENST00000262795  protein_coding          4558       YES  0.123
#
#               pext NMD_escape
# 102377    0.848889         NO
# 104819    0.848889         NO
# 107720    0.956129         NO
# 131443    0.928222         NO
# 131598    0.928222         NO
# ...            ...        ...
# 33343503  0.771752         NO
# 33494384  1.000000         NO
# 33496274  1.000000         NO
# 33497124  1.000000         NO
# 33497214  1.000000         NO
#
# [935 rows x 20 columns]

# %%
pat_nmd.shape[0] + clinvar_nmd.shape[0]
# Out:
# 11684

# %%
merged_clinvar_and_pat = pat_nmd.merge(clinvar_nmd, on=['CHROM', 'POS', 'REF', 'ALT'], how='outer', indicator=True)
merged_clinvar_and_pat
# Out:
#       CHROM        POS         rsID REF ALT Impact Consequence_x Gene_symbol  \
# 0      chr1    1825438  rs867938404   G   A   HIGH   stop_gained        GNB1
# 1      chr1    2019468            .   C   A   HIGH   stop_gained       GABRD
# 2      chr1    2024966            .   C   A   HIGH   stop_gained       GABRD
# 3      chr1    2024966            .   C   G   HIGH   stop_gained       GABRD
# 4      chr1    2024993            .   G   A   HIGH   stop_gained       GABRD
# ...     ...        ...          ...  ..  ..    ...           ...         ...
# 11609  chr9  138118724            .   C   T   HIGH   stop_gained     CACNA1B
# 11610  chr9  138120738            .   C   T   HIGH   stop_gained     CACNA1B
# 11611  chr9  138120765            .   C   T   HIGH   stop_gained     CACNA1B
# 11612  chr9  138120776            .   C   A   HIGH   stop_gained     CACNA1B
# 11613  chr9  138120782  rs201782791   C   A   HIGH   stop_gained     CACNA1B
#
#       Canonical_transcript_x cDNA_position_x  ... Gene Feature_type  \
# 0            ENST00000378609             379  ...  NaN          NaN
# 1            ENST00000378585             124  ...  NaN          NaN
# 2            ENST00000378585             172  ...  NaN          NaN
# 3            ENST00000378585             172  ...  NaN          NaN
# 4            ENST00000378585             199  ...  NaN          NaN
# ...                      ...             ...  ...  ...          ...
# 11609        ENST00000371372            6138  ...  NaN          NaN
# 11610        ENST00000371372            6498  ...  NaN          NaN
# 11611        ENST00000371372            6525  ...  NaN          NaN
# 11612        ENST00000371372            6536  ...  NaN          NaN
# 11613        ENST00000371372            6542  ...  NaN          NaN
#
#       Canonical_transcript_y  BIOTYPE  cDNA_position_y  CANONICAL LOEUF_y  \
# 0                        NaN      NaN              NaN        NaN     NaN
# 1                        NaN      NaN              NaN        NaN     NaN
# 2                        NaN      NaN              NaN        NaN     NaN
# 3                        NaN      NaN              NaN        NaN     NaN
# 4                        NaN      NaN              NaN        NaN     NaN
# ...                      ...      ...              ...        ...     ...
# 11609                    NaN      NaN              NaN        NaN     NaN
# 11610                    NaN      NaN              NaN        NaN     NaN
# 11611                    NaN      NaN              NaN        NaN     NaN
# 11612                    NaN      NaN              NaN        NaN     NaN
# 11613                    NaN      NaN              NaN        NaN     NaN
#
#        pext_y NMD_escape_y     _merge
# 0         NaN          NaN  left_only
# 1         NaN          NaN  left_only
# 2         NaN          NaN  left_only
# 3         NaN          NaN  left_only
# 4         NaN          NaN  left_only
# ...       ...          ...        ...
# 11609     NaN          NaN  left_only
# 11610     NaN          NaN  left_only
# 11611     NaN          NaN  left_only
# 11612     NaN          NaN  left_only
# 11613     NaN          NaN  left_only
#
# [11614 rows x 34 columns]

# %%
pat_nmd_filtered = merged_clinvar_and_pat.drop_duplicates(subset=['CHROM', 'POS', 'REF', 'ALT'], keep='first', ignore_index=True)
pat_nmd_filtered
# Out:
#       CHROM        POS         rsID REF ALT Impact Consequence_x Gene_symbol  \
# 0      chr1    1825438  rs867938404   G   A   HIGH   stop_gained        GNB1
# 1      chr1    2019468            .   C   A   HIGH   stop_gained       GABRD
# 2      chr1    2024966            .   C   A   HIGH   stop_gained       GABRD
# 3      chr1    2024966            .   C   G   HIGH   stop_gained       GABRD
# 4      chr1    2024993            .   G   A   HIGH   stop_gained       GABRD
# ...     ...        ...          ...  ..  ..    ...           ...         ...
# 11609  chr9  138118724            .   C   T   HIGH   stop_gained     CACNA1B
# 11610  chr9  138120738            .   C   T   HIGH   stop_gained     CACNA1B
# 11611  chr9  138120765            .   C   T   HIGH   stop_gained     CACNA1B
# 11612  chr9  138120776            .   C   A   HIGH   stop_gained     CACNA1B
# 11613  chr9  138120782  rs201782791   C   A   HIGH   stop_gained     CACNA1B
#
#       Canonical_transcript_x cDNA_position_x  ... Gene Feature_type  \
# 0            ENST00000378609             379  ...  NaN          NaN
# 1            ENST00000378585             124  ...  NaN          NaN
# 2            ENST00000378585             172  ...  NaN          NaN
# 3            ENST00000378585             172  ...  NaN          NaN
# 4            ENST00000378585             199  ...  NaN          NaN
# ...                      ...             ...  ...  ...          ...
# 11609        ENST00000371372            6138  ...  NaN          NaN
# 11610        ENST00000371372            6498  ...  NaN          NaN
# 11611        ENST00000371372            6525  ...  NaN          NaN
# 11612        ENST00000371372            6536  ...  NaN          NaN
# 11613        ENST00000371372            6542  ...  NaN          NaN
#
#       Canonical_transcript_y  BIOTYPE  cDNA_position_y  CANONICAL LOEUF_y  \
# 0                        NaN      NaN              NaN        NaN     NaN
# 1                        NaN      NaN              NaN        NaN     NaN
# 2                        NaN      NaN              NaN        NaN     NaN
# 3                        NaN      NaN              NaN        NaN     NaN
# 4                        NaN      NaN              NaN        NaN     NaN
# ...                      ...      ...              ...        ...     ...
# 11609                    NaN      NaN              NaN        NaN     NaN
# 11610                    NaN      NaN              NaN        NaN     NaN
# 11611                    NaN      NaN              NaN        NaN     NaN
# 11612                    NaN      NaN              NaN        NaN     NaN
# 11613                    NaN      NaN              NaN        NaN     NaN
#
#        pext_y NMD_escape_y     _merge
# 0         NaN          NaN  left_only
# 1         NaN          NaN  left_only
# 2         NaN          NaN  left_only
# 3         NaN          NaN  left_only
# 4         NaN          NaN  left_only
# ...       ...          ...        ...
# 11609     NaN          NaN  left_only
# 11610     NaN          NaN  left_only
# 11611     NaN          NaN  left_only
# 11612     NaN          NaN  left_only
# 11613     NaN          NaN  left_only
#
# [11614 rows x 34 columns]

# %% [markdown]
# Проверим, остались ли дубликаты:

# %%
duplicates = pat_nmd_filtered[pat_nmd_filtered.duplicated(subset=['CHROM', 'POS', 'ALT'], keep=False)]
duplicates
# Out:
# Empty DataFrame
# Columns: [CHROM, POS, rsID, REF, ALT, Impact, Consequence_x, Gene_symbol, Canonical_transcript_x, cDNA_position_x, LoF, LoF_flag, LoF_filter, AC, LOEUF_x, pext_x, NMD_escape_x, ID, CLNSIG, CLNVC, GENEINFO, MC, Consequence_y, SYMBOL, Gene, Feature_type, Canonical_transcript_y, BIOTYPE, cDNA_position_y, CANONICAL, LOEUF_y, pext_y, NMD_escape_y, _merge]
# Index: []
#
# [0 rows x 34 columns]

# %%
pat_nmd_filtered
# Out:
#       CHROM        POS         rsID REF ALT Impact Consequence_x Gene_symbol  \
# 0      chr1    1825438  rs867938404   G   A   HIGH   stop_gained        GNB1
# 1      chr1    2019468            .   C   A   HIGH   stop_gained       GABRD
# 2      chr1    2024966            .   C   A   HIGH   stop_gained       GABRD
# 3      chr1    2024966            .   C   G   HIGH   stop_gained       GABRD
# 4      chr1    2024993            .   G   A   HIGH   stop_gained       GABRD
# ...     ...        ...          ...  ..  ..    ...           ...         ...
# 11609  chr9  138118724            .   C   T   HIGH   stop_gained     CACNA1B
# 11610  chr9  138120738            .   C   T   HIGH   stop_gained     CACNA1B
# 11611  chr9  138120765            .   C   T   HIGH   stop_gained     CACNA1B
# 11612  chr9  138120776            .   C   A   HIGH   stop_gained     CACNA1B
# 11613  chr9  138120782  rs201782791   C   A   HIGH   stop_gained     CACNA1B
#
#       Canonical_transcript_x cDNA_position_x  ... Gene Feature_type  \
# 0            ENST00000378609             379  ...  NaN          NaN
# 1            ENST00000378585             124  ...  NaN          NaN
# 2            ENST00000378585             172  ...  NaN          NaN
# 3            ENST00000378585             172  ...  NaN          NaN
# 4            ENST00000378585             199  ...  NaN          NaN
# ...                      ...             ...  ...  ...          ...
# 11609        ENST00000371372            6138  ...  NaN          NaN
# 11610        ENST00000371372            6498  ...  NaN          NaN
# 11611        ENST00000371372            6525  ...  NaN          NaN
# 11612        ENST00000371372            6536  ...  NaN          NaN
# 11613        ENST00000371372            6542  ...  NaN          NaN
#
#       Canonical_transcript_y  BIOTYPE  cDNA_position_y  CANONICAL LOEUF_y  \
# 0                        NaN      NaN              NaN        NaN     NaN
# 1                        NaN      NaN              NaN        NaN     NaN
# 2                        NaN      NaN              NaN        NaN     NaN
# 3                        NaN      NaN              NaN        NaN     NaN
# 4                        NaN      NaN              NaN        NaN     NaN
# ...                      ...      ...              ...        ...     ...
# 11609                    NaN      NaN              NaN        NaN     NaN
# 11610                    NaN      NaN              NaN        NaN     NaN
# 11611                    NaN      NaN              NaN        NaN     NaN
# 11612                    NaN      NaN              NaN        NaN     NaN
# 11613                    NaN      NaN              NaN        NaN     NaN
#
#        pext_y NMD_escape_y     _merge
# 0         NaN          NaN  left_only
# 1         NaN          NaN  left_only
# 2         NaN          NaN  left_only
# 3         NaN          NaN  left_only
# 4         NaN          NaN  left_only
# ...       ...          ...        ...
# 11609     NaN          NaN  left_only
# 11610     NaN          NaN  left_only
# 11611     NaN          NaN  left_only
# 11612     NaN          NaN  left_only
# 11613     NaN          NaN  left_only
#
# [11614 rows x 34 columns]

# %%
pat_nmd_filtered.columns
# Out:
# Index(['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Impact', 'Consequence_x',
#        'Gene_symbol', 'Canonical_transcript_x', 'cDNA_position_x', 'LoF',
#        'LoF_flag', 'LoF_filter', 'AC', 'LOEUF_x', 'pext_x', 'NMD_escape_x',
#        'ID', 'CLNSIG', 'CLNVC', 'GENEINFO', 'MC', 'Consequence_y', 'SYMBOL',
#        'Gene', 'Feature_type', 'Canonical_transcript_y', 'BIOTYPE',
#        'cDNA_position_y', 'CANONICAL', 'LOEUF_y', 'pext_y', 'NMD_escape_y',
#        '_merge'],
#       dtype='object')

# %% [markdown]
# Наводим красоту в шапке:

# %%
pat_nmd_filtered['Canonical_transcript_x'] = pat_nmd_filtered['Canonical_transcript_x'].fillna(pat_nmd_filtered['Canonical_transcript_y'])
pat_nmd_filtered['cDNA_position_x'] = pat_nmd_filtered['cDNA_position_x'].fillna(pat_nmd_filtered['cDNA_position_y'])
pat_nmd_filtered['Consequence_x'] = pat_nmd_filtered['Consequence_x'].fillna(pat_nmd_filtered['Consequence_y'])
pat_nmd_filtered['LOEUF_x'] = pat_nmd_filtered['LOEUF_x'].fillna(pat_nmd_filtered['LOEUF_y'])
pat_nmd_filtered['Gene_symbol'] = pat_nmd_filtered['Gene_symbol'].fillna(pat_nmd_filtered['SYMBOL'])
pat_nmd_filtered['NMD_escape_x'] = pat_nmd_filtered['NMD_escape_x'].fillna(pat_nmd_filtered['NMD_escape_y'])
pat_nmd_filtered['pext_x'] = pat_nmd_filtered['pext_x'].fillna(pat_nmd_filtered['pext_y'])

pat_nmd_filtered
# Out:
#       CHROM        POS         rsID REF ALT Impact Consequence_x Gene_symbol  \
# 0      chr1    1825438  rs867938404   G   A   HIGH   stop_gained        GNB1
# 1      chr1    2019468            .   C   A   HIGH   stop_gained       GABRD
# 2      chr1    2024966            .   C   A   HIGH   stop_gained       GABRD
# 3      chr1    2024966            .   C   G   HIGH   stop_gained       GABRD
# 4      chr1    2024993            .   G   A   HIGH   stop_gained       GABRD
# ...     ...        ...          ...  ..  ..    ...           ...         ...
# 11609  chr9  138118724            .   C   T   HIGH   stop_gained     CACNA1B
# 11610  chr9  138120738            .   C   T   HIGH   stop_gained     CACNA1B
# 11611  chr9  138120765            .   C   T   HIGH   stop_gained     CACNA1B
# 11612  chr9  138120776            .   C   A   HIGH   stop_gained     CACNA1B
# 11613  chr9  138120782  rs201782791   C   A   HIGH   stop_gained     CACNA1B
#
#       Canonical_transcript_x cDNA_position_x  ... Gene Feature_type  \
# 0            ENST00000378609             379  ...  NaN          NaN
# 1            ENST00000378585             124  ...  NaN          NaN
# 2            ENST00000378585             172  ...  NaN          NaN
# 3            ENST00000378585             172  ...  NaN          NaN
# 4            ENST00000378585             199  ...  NaN          NaN
# ...                      ...             ...  ...  ...          ...
# 11609        ENST00000371372            6138  ...  NaN          NaN
# 11610        ENST00000371372            6498  ...  NaN          NaN
# 11611        ENST00000371372            6525  ...  NaN          NaN
# 11612        ENST00000371372            6536  ...  NaN          NaN
# 11613        ENST00000371372            6542  ...  NaN          NaN
#
#       Canonical_transcript_y  BIOTYPE  cDNA_position_y  CANONICAL LOEUF_y  \
# 0                        NaN      NaN              NaN        NaN     NaN
# 1                        NaN      NaN              NaN        NaN     NaN
# 2                        NaN      NaN              NaN        NaN     NaN
# 3                        NaN      NaN              NaN        NaN     NaN
# 4                        NaN      NaN              NaN        NaN     NaN
# ...                      ...      ...              ...        ...     ...
# 11609                    NaN      NaN              NaN        NaN     NaN
# 11610                    NaN      NaN              NaN        NaN     NaN
# 11611                    NaN      NaN              NaN        NaN     NaN
# 11612                    NaN      NaN              NaN        NaN     NaN
# 11613                    NaN      NaN              NaN        NaN     NaN
#
#        pext_y NMD_escape_y     _merge
# 0         NaN          NaN  left_only
# 1         NaN          NaN  left_only
# 2         NaN          NaN  left_only
# 3         NaN          NaN  left_only
# 4         NaN          NaN  left_only
# ...       ...          ...        ...
# 11609     NaN          NaN  left_only
# 11610     NaN          NaN  left_only
# 11611     NaN          NaN  left_only
# 11612     NaN          NaN  left_only
# 11613     NaN          NaN  left_only
#
# [11614 rows x 34 columns]

# %%
pat_nmd_filtered.columns
# Out:
# Index(['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Impact', 'Consequence_x',
#        'Gene_symbol', 'Canonical_transcript_x', 'cDNA_position_x', 'LoF',
#        'LoF_flag', 'LoF_filter', 'AC', 'LOEUF_x', 'pext_x', 'NMD_escape_x',
#        'ID', 'CLNSIG', 'CLNVC', 'GENEINFO', 'MC', 'Consequence_y', 'SYMBOL',
#        'Gene', 'Feature_type', 'Canonical_transcript_y', 'BIOTYPE',
#        'cDNA_position_y', 'CANONICAL', 'LOEUF_y', 'pext_y', 'NMD_escape_y',
#        '_merge'],
#       dtype='object')

# %%
pat_nmd_filtered = pat_nmd_filtered.drop(columns=['ID', 'CLNSIG', 'CLNVC', 'GENEINFO', 'MC', 'Consequence_y', 
                                                'SYMBOL', 'Gene', 'Feature_type', 'Canonical_transcript_y', 
                                                'BIOTYPE', 'cDNA_position_y', 'CANONICAL', '_merge', 'LOEUF_y', 'NMD_escape_y', 'pext_y'])

pat_nmd_filtered = pat_nmd_filtered.rename(columns={'cDNA_position_x': 'cDNA_position', 
                                                  'Canonical_transcript_x': 'Canonical_transcript', 
                                                  'Consequence_x': 'Consequence', 'LOEUF_x': 'LOEUF', 
                                                  'NMD_escape_x':'NMD_escape', 'pext_x': 'pext'})
pat_nmd_filtered
# Out:
#       CHROM        POS         rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1    1825438  rs867938404   G   A   HIGH  stop_gained        GNB1
# 1      chr1    2019468            .   C   A   HIGH  stop_gained       GABRD
# 2      chr1    2024966            .   C   A   HIGH  stop_gained       GABRD
# 3      chr1    2024966            .   C   G   HIGH  stop_gained       GABRD
# 4      chr1    2024993            .   G   A   HIGH  stop_gained       GABRD
# ...     ...        ...          ...  ..  ..    ...          ...         ...
# 11609  chr9  138118724            .   C   T   HIGH  stop_gained     CACNA1B
# 11610  chr9  138120738            .   C   T   HIGH  stop_gained     CACNA1B
# 11611  chr9  138120765            .   C   T   HIGH  stop_gained     CACNA1B
# 11612  chr9  138120776            .   C   A   HIGH  stop_gained     CACNA1B
# 11613  chr9  138120782  rs201782791   C   A   HIGH  stop_gained     CACNA1B
#
#       Canonical_transcript cDNA_position LoF       LoF_flag LoF_filter   AC  \
# 0          ENST00000378609           379  HC            NaN        NaN  1.0
# 1          ENST00000378585           124  HC  PHYLOCSF_WEAK        NaN  1.0
# 2          ENST00000378585           172  HC            NaN        NaN  1.0
# 3          ENST00000378585           172  HC            NaN        NaN  1.0
# 4          ENST00000378585           199  HC            NaN        NaN  1.0
# ...                    ...           ...  ..            ...        ...  ...
# 11609      ENST00000371372          6138  HC            NaN        NaN  1.0
# 11610      ENST00000371372          6498  HC            NaN        NaN  1.0
# 11611      ENST00000371372          6525  HC            NaN        NaN  1.0
# 11612      ENST00000371372          6536  HC            NaN        NaN  1.0
# 11613      ENST00000371372          6542  HC            NaN        NaN  1.0
#
#        LOEUF      pext NMD_escape
# 0      0.145  0.966547         NO
# 1      0.245  1.000000         NO
# 2      0.245  1.000000         NO
# 3      0.245  1.000000         NO
# 4      0.245  1.000000         NO
# ...      ...       ...        ...
# 11609  0.240  0.976450         NO
# 11610  0.240  0.976450         NO
# 11611  0.240  0.976450         NO
# 11612  0.240  0.976450         NO
# 11613  0.240  0.976450         NO
#
# [11614 rows x 17 columns]

# %%
pat_nmd_filtered.columns
# Out:
# Index(['CHROM', 'POS', 'rsID', 'REF', 'ALT', 'Impact', 'Consequence',
#        'Gene_symbol', 'Canonical_transcript', 'cDNA_position', 'LoF',
#        'LoF_flag', 'LoF_filter', 'AC', 'LOEUF', 'pext', 'NMD_escape'],
#       dtype='object')

# %% [markdown]
# Было без Клинвара вот так:

# %%
pat_nmd.shape
# Out:
# (10749, 17)

# %% [markdown]
# Добавим позицию в кодоне:

# %%
rows_to_remove = pat_nmd_filtered[pat_nmd_filtered['cDNA_position'].str.contains("-")].index
pat_nmd_filtered = pat_nmd_filtered.drop(rows_to_remove)

pat_nmd_filtered['cDNA_position'] = pat_nmd_filtered['cDNA_position'].astype(int)

pat_nmd_filtered['Codon_position'] = np.where(pat_nmd_filtered['cDNA_position'] % 3 == 1, 1,
                                           np.where(pat_nmd_filtered['cDNA_position'] % 3 == 2, 2, 
                                                    3))

pat_nmd_filtered
# Out:
#       CHROM        POS         rsID REF ALT Impact  Consequence Gene_symbol  \
# 0      chr1    1825438  rs867938404   G   A   HIGH  stop_gained        GNB1
# 1      chr1    2019468            .   C   A   HIGH  stop_gained       GABRD
# 2      chr1    2024966            .   C   A   HIGH  stop_gained       GABRD
# 3      chr1    2024966            .   C   G   HIGH  stop_gained       GABRD
# 4      chr1    2024993            .   G   A   HIGH  stop_gained       GABRD
# ...     ...        ...          ...  ..  ..    ...          ...         ...
# 11609  chr9  138118724            .   C   T   HIGH  stop_gained     CACNA1B
# 11610  chr9  138120738            .   C   T   HIGH  stop_gained     CACNA1B
# 11611  chr9  138120765            .   C   T   HIGH  stop_gained     CACNA1B
# 11612  chr9  138120776            .   C   A   HIGH  stop_gained     CACNA1B
# 11613  chr9  138120782  rs201782791   C   A   HIGH  stop_gained     CACNA1B
#
#       Canonical_transcript  cDNA_position LoF       LoF_flag LoF_filter   AC  \
# 0          ENST00000378609            379  HC            NaN        NaN  1.0
# 1          ENST00000378585            124  HC  PHYLOCSF_WEAK        NaN  1.0
# 2          ENST00000378585            172  HC            NaN        NaN  1.0
# 3          ENST00000378585            172  HC            NaN        NaN  1.0
# 4          ENST00000378585            199  HC            NaN        NaN  1.0
# ...                    ...            ...  ..            ...        ...  ...
# 11609      ENST00000371372           6138  HC            NaN        NaN  1.0
# 11610      ENST00000371372           6498  HC            NaN        NaN  1.0
# 11611      ENST00000371372           6525  HC            NaN        NaN  1.0
# 11612      ENST00000371372           6536  HC            NaN        NaN  1.0
# 11613      ENST00000371372           6542  HC            NaN        NaN  1.0
#
#        LOEUF      pext NMD_escape  Codon_position
# 0      0.145  0.966547         NO               1
# 1      0.245  1.000000         NO               1
# 2      0.245  1.000000         NO               1
# 3      0.245  1.000000         NO               1
# 4      0.245  1.000000         NO               1
# ...      ...       ...        ...             ...
# 11609  0.240  0.976450         NO               3
# 11610  0.240  0.976450         NO               3
# 11611  0.240  0.976450         NO               3
# 11612  0.240  0.976450         NO               2
# 11613  0.240  0.976450         NO               2
#
# [11614 rows x 18 columns]

# %% [markdown]
# **Датафрейм с условно патогенными вариантами готов.**

# %% [markdown]
# ### Сбалансируем датафреймы

# %% [markdown]
# Для этого в обоих дф оставим только те гены, которые встречаются и в пат, и в бен, а также уравняем количество вариантов в них.

# %%
unique_genes_ben = ben_nmd_filtered['Gene_symbol'].unique()
unique_genes_pat = pat_nmd_filtered['Gene_symbol'].unique()

# Находим пересечение уникальных значений 'Gene_symbol'
intersected_genes = np.intersect1d(unique_genes_pat, unique_genes_ben)

print("Всего уникальных генов в pat:", len(unique_genes_pat))
print("Всего уникальных генов в ben:", len(unique_genes_ben))
print("Количество пересекающихся генов:", len(intersected_genes))
# Out:
# Всего уникальных генов в pat: 1394
# Всего уникальных генов в ben: 952
# Количество пересекающихся генов: 932

# %%
common_genes = set(unique_genes_ben) & set(unique_genes_pat)

# Оставляем только те строки, где значение гена присутствует в обоих дф
ben_nmd_filtered = ben_nmd_filtered[ben_nmd_filtered['Gene_symbol'].isin(common_genes)]
pat_nmd_filtered = pat_nmd_filtered[pat_nmd_filtered['Gene_symbol'].isin(common_genes)]

# %%
unique_genes_pat = pat_nmd_filtered['Gene_symbol'].unique()
unique_genes_ben = ben_nmd_filtered['Gene_symbol'].unique()

intersected_genes = np.intersect1d(unique_genes_pat, unique_genes_ben)

print("Всего уникальных генов в pat:", len(unique_genes_pat))
print("Всего уникальных генов в ben:", len(unique_genes_ben))
print("Количество пересекающихся генов:", len(intersected_genes))
# Out:
# Всего уникальных генов в pat: 932
# Всего уникальных генов в ben: 932
# Количество пересекающихся генов: 932

# %%
count_pat = pat_nmd_filtered['Gene_symbol'].value_counts()
count_ben = ben_nmd_filtered['Gene_symbol'].value_counts()

min_counts = pd.concat([count_pat, count_ben], axis=1).min(axis=1)

pat_nmd_final = pd.concat([
    pat_nmd_filtered[pat_nmd_filtered['Gene_symbol'] == gene].sample(n=min_count, random_state=42) \
    for gene, min_count in min_counts.items()
])

ben_nmd_final = pd.concat([
    ben_nmd_filtered[ben_nmd_filtered['Gene_symbol'] == gene].sample(n=min_count, random_state=42) \
    for gene, min_count in min_counts.items()
])

# %%
pat_nmd_final.shape == ben_nmd_final.shape
# Out:
# True

# %%
pat_nmd_final['Gene_symbol'].nunique() == ben_nmd_final['Gene_symbol'].nunique()
# Out:
# True

# %%
pat_nmd_final['Gene_symbol'].value_counts().sum() == ben_nmd_final['Gene_symbol'].value_counts().sum()
# Out:
# True

# %%
pat_nmd_final['Gene_symbol'].nunique()
# Out:
# 932

# %% [markdown]
# Теперь датафреймы сбалансированы по генам и количеству вариантов.

# %% [markdown]
# ### Посмотрим на распределение кДНК позиций относительно начала и конца транскриптов

# %% [markdown]
# Получаем словарь с длинами транскриптов и записываем % расположение варианта в датафрейм:

# %%
transcript_fasta = Fasta("data_dir/gencode_data/gencode.v45.transcripts.fa.gz", key_function = lambda x: x.split('.')[0])

# %%
transcript_lengths = {}
for key in transcript_fasta.keys():
    transcript_lengths[key] = len(transcript_fasta[key])

# %%
def check_and_divide(row):
    transcript = row['Canonical_transcript']
    if transcript in transcript_lengths:
        return (row['cDNA_position'] / transcript_lengths[transcript]) * 100
    return None

# %%
pat_nmd_final['Percent_position'] = pat_nmd_final.apply(check_and_divide, axis=1)

# %%
ben_nmd_final['Percent_position'] = ben_nmd_final.apply(check_and_divide, axis=1)

# %%
ben_nmd_final.describe()
# Out:
#                 POS  cDNA_position           AC        LOEUF         pext  \
# count  3.424000e+03    3424.000000  3424.000000  3424.000000  3424.000000
# mean   7.855760e+07    2032.739778     3.627336     0.252413     0.844550
# std    5.697018e+07    1765.196475     7.583337     0.067303     0.146743
# min    1.633370e+05      31.000000     2.000000     0.030000     0.502500
# 25%    3.680970e+07     846.500000     2.000000     0.203000     0.732126
# 50%    6.536482e+07    1528.500000     2.000000     0.260000     0.886530
# 75%    1.141982e+08    2677.750000     4.000000     0.308000     0.976511
# max    2.456990e+08   14290.000000   284.000000     0.349000     1.000000
#
#        Codon_position  Percent_position
# count     3424.000000       3424.000000
# mean         1.980724         29.312811
# std          0.827995         18.818645
# min          1.000000          0.611812
# 25%          1.000000         14.077207
# 50%          2.000000         25.445309
# 75%          3.000000         41.373719
# max          3.000000         92.194009

# %%
ben_nmd_final['Percent_position'].idxmin()
# Out:
# 1633

# %%
ben_nmd_final.loc[560]
# Out:
# CHROM                              chr2
# POS                           165113899
# rsID                       rs1553520070
# REF                                   G
# ALT                                   A
# Impact                             HIGH
# Consequence                 stop_gained
# Gene_symbol                       SCN3A
# Canonical_transcript    ENST00000283254
# cDNA_position                      4061
# LoF                                  HC
# LoF_flag                            NaN
# LoF_filter                          NaN
# AC                                  2.0
# LOEUF                             0.174
# pext                            0.90262
# NMD_escape                           NO
# Codon_position                        2
# Percent_position              44.616568
# Name: 560, dtype: object

# %%
transcript_lengths['ENST00000242310']
# Out:
# 6216

# %% [markdown]
# Визуализируем распределение вариантов:

# %%
def extract_number(chrom):  # чтобы chr не мешало
    return int(chrom[3:])

# %%
pat_nmd_final_sorted = pat_nmd_final.copy()
pat_nmd_final_sorted['CHROM'] = pat_nmd_final_sorted['CHROM'].apply(extract_number)
pat_nmd_final_sorted = pat_nmd_final_sorted.sort_values(by='CHROM')

# %%
ben_nmd_final_sorted = ben_nmd_final.copy()
ben_nmd_final_sorted['CHROM'] = ben_nmd_final_sorted['CHROM'].apply(extract_number)
ben_nmd_final_sorted = ben_nmd_final_sorted.sort_values(by='CHROM')

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(y='Percent_position', data=pat_nmd_final_sorted, color='crimson')
plt.title('Violin plot of PAT variant position relative to transcript boundaries')
plt.xlabel('Percent_position')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(y='Percent_position', data=ben_nmd_final_sorted, color='crimson')
plt.title('Violin plot of BEN variant position relative to transcript boundaries')
plt.xlabel('Percent_position')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(x='CHROM', y='Percent_position', data=pat_nmd_final_sorted, hue='CHROM', palette='coolwarm', legend=False)
plt.title('Violin plot of PAT variant position relative to transcript boundaries')
plt.xlabel('CHROM')
plt.ylabel('Percent_position')
plt.show()

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(x='CHROM', y='Percent_position', data=ben_nmd_final_sorted, hue='CHROM', palette='coolwarm', legend=False)
plt.title('Violin plot of BEN variant position relative to transcript boundaries')
plt.xlabel('CHROM')
plt.ylabel('Percent_position')
plt.show()

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(x='Codon_position', y='Percent_position', data=pat_nmd_final_sorted, hue='Codon_position', palette='coolwarm', legend=False)
plt.title('Violin plot of PAT variant positions relative to transcript boundaries')
plt.xlabel('Codon_position')
plt.ylabel('Percent_position')
plt.show()

# %%
plt.figure(figsize=(15, 4))
sns.violinplot(x='Codon_position', y='Percent_position', data=ben_nmd_final_sorted, hue='Codon_position', palette='coolwarm', legend=False)
plt.title('Violin plot of BEN variant position relative to transcript boundaries')
plt.xlabel('Codon_position')
plt.ylabel('Percent_position')
plt.show()

# %% [markdown]
# ### Получение контекста последовательности

# %% [markdown]
# В таблице есть пустые поля в столбце `cDNA_position`, при итерации они отмечаются как `nan` (т.е. `<class 'float'>`). Если значение не пустое, оно имеет тип `str`, так что для работы `pyfaidx` приходится приводить его к `int`.

# %% [markdown]
# **Пропускаем позиции, которые слишком близко (`<=5`) к началу или концу транскрипта.**

# %% [markdown]
# Записываем контекст в отдельную колонку датафрейма.

# %%
def get_context(df, transcript_fasta, left_len, right_len):
    contexts = []

    for index, row in df.iterrows():
        transcript_id = row['Canonical_transcript']
        position_of_interest = row['cDNA_position']

        # Транскрипта может не быть в базе
        if transcript_id in transcript_fasta:
            transcript_length = len(transcript_fasta[transcript_id])

            # Не рассматриваем крайние случаи
            if left_len < position_of_interest < transcript_length - right_len:
                sequence_of_interest = str(transcript_fasta[transcript_id][position_of_interest - left_len: position_of_interest + right_len])
            else:
                sequence_of_interest = None
        else:
            sequence_of_interest = None
        
        contexts.append(sequence_of_interest)

    df['Context'] = contexts
    message = 'Contexts have been added to the dataframe!'

    return message

# %%
transcript_fasta = Fasta("data_dir/gencode_data/gencode.v45.transcripts.fa.gz", key_function = lambda x: x.split('.')[0])

# %% [markdown]
# Разделим датафреймы по положению варианта в кодоне.

# %%
ben_nmd_final_1 = ben_nmd_final.loc[ben_nmd_final['Codon_position'] == 1].copy()
ben_nmd_final_2 = ben_nmd_final.loc[ben_nmd_final['Codon_position'] == 2].copy()
ben_nmd_final_3 = ben_nmd_final.loc[ben_nmd_final['Codon_position'] == 3].copy()

# %%
pat_nmd_final_1 = pat_nmd_final.loc[pat_nmd_final['Codon_position'] == 1].copy()
pat_nmd_final_2 = pat_nmd_final.loc[pat_nmd_final['Codon_position'] == 2].copy()
pat_nmd_final_3 = pat_nmd_final.loc[pat_nmd_final['Codon_position'] == 3].copy()

# %% [markdown]
# Получим контексты:

# %%
get_context(ben_nmd_final_1, transcript_fasta, 5, 7)
get_context(ben_nmd_final_2, transcript_fasta, 6, 6)
get_context(ben_nmd_final_3, transcript_fasta, 7, 5)
# Out:
# 'Contexts have been added to the dataframe!'

# %%
get_context(pat_nmd_final_1, transcript_fasta, 5, 7)
get_context(pat_nmd_final_2, transcript_fasta, 6, 6)
get_context(pat_nmd_final_3, transcript_fasta, 7, 5)
# Out:
# 'Contexts have been added to the dataframe!'

# %% [markdown]
# ### Построение лого с помощью logomaker

# %% [markdown]
# https://github.com/jbkinney/logomaker/blob/master/logomaker/tutorials
#
# https://logomaker.readthedocs.io/en/latest/

# %% [markdown]
# Сам всё делает, надо только подать список последовательностей, удалив пустые значения.

# %%
def filter_and_convert_to_list(column):
    filtered_list = column.tolist()
    filtered_list = list(filter(None, filtered_list))
    return filtered_list

# %%
filtered_context_ben_1 = filter_and_convert_to_list(ben_nmd_final_1['Context'])
filtered_context_ben_2 = filter_and_convert_to_list(ben_nmd_final_2['Context'])
filtered_context_ben_3 = filter_and_convert_to_list(ben_nmd_final_3['Context'])

# %%
filtered_context_pat_1 = filter_and_convert_to_list(pat_nmd_final_1['Context'])
filtered_context_pat_2 = filter_and_convert_to_list(pat_nmd_final_2['Context'])
filtered_context_pat_3 = filter_and_convert_to_list(pat_nmd_final_3['Context'])

# %% [markdown]
# Строим матрицы.

# %%
counts_mat_pat_1 = lm.alignment_to_matrix(filtered_context_pat_1)
counts_mat_ben_1 = lm.alignment_to_matrix(filtered_context_ben_1)

# %%
pat_logo = lm.Logo(counts_mat_pat_1, 
                   figsize=(6, 3),
                   font_name='Liberation Sans')
pat_logo.style_xticks()

# %%
ben_logo = lm.Logo(counts_mat_ben_1, 
                   figsize=(6, 3),
                   font_name='Liberation Sans')
ben_logo.style_xticks()

# %% [markdown]
# Окрашивание по base_pairing:

# %%
# pat_logo = lm.Logo(counts_mat_pat, 
#                    figsize=(6, 3),
#                    color_scheme='base_pairing',
#                    font_name='Liberation Sans')
# pat_logo.style_xticks()

# ben_logo = lm.Logo(counts_mat_ben, 
#                    figsize=(6, 3),
#                    color_scheme='base_pairing',
#                    font_name='Liberation Sans')
# ben_logo.style_xticks()

# %% [markdown]
# Можно ещё по вероятностям строить:

# %%
# prob_mat_pat = lm.transform_matrix(counts_mat_pat, from_type='counts', to_type='probability')
# prob_mat_ben = lm.transform_matrix(counts_mat_ben, from_type='counts', to_type='probability')

# %% [markdown]
# ### Статистическое сравнение позиций в контекстах

# %% [markdown]
# Виды позиционных матриц:
#
# **Position Frequency Matrix (PFM)**:
# В ячейках PFM содержатся частоты каждого нуклеотида на соответствующей позиции в наборе последовательностей.
# PFM не нормализуется по вероятностям, поэтому сумма значений в каждой строке может быть больше 1.
#
# **Position Probability Matrix (PPM)**:
# В отличие от PFM, значения в PPM нормализуются по вероятностям, так что сумма значений в каждой строке равна 1.
# PPM показывает вероятность появления каждого нуклеотида на каждой позиции в последовательности.
#
# **Position Weight Matrix (PWM)**:
# Значения в PWM выражены в виде весов, которые показывают предпочтительность каждого нуклеотида на каждой позиции. Веса обычно вычисляются как логарифм отношения частоты наблюдения нуклеотида к ожидаемой частоте нуклеотида на данной позиции.

# %% [markdown]
# Считаем хи-квадраты для каждой позиции при сравнении двух матриц:

# %%
def calculate_chi2_p_values(context_ben, context_pat):
    # Преобразование списка контекстов в массив нампай
    sequences_array_ben = np.array(context_ben)
    sequences_array_pat = np.array(context_pat)

    # Создание пустого массива для хранения частот
    freq_array_ben = np.zeros((len(sequences_array_ben[0]), 4))
    freq_array_pat = np.zeros((len(sequences_array_pat[0]), 4))

    # Вычисление частоты каждой буквы на каждой позиции
    for seq in sequences_array_ben:
        for j, nt in enumerate(seq):
            if nt == 'A':
                freq_array_ben[j][0] += 1
            elif nt == 'C':
                freq_array_ben[j][1] += 1
            elif nt == 'G':
                freq_array_ben[j][2] += 1
            elif nt == 'T':
                freq_array_ben[j][3] += 1

    for seq in sequences_array_pat:
        for j, nt in enumerate(seq):
            if nt == 'A':
                freq_array_pat[j][0] += 1
            elif nt == 'C':
                freq_array_pat[j][1] += 1
            elif nt == 'G':
                freq_array_pat[j][2] += 1
            elif nt == 'T':
                freq_array_pat[j][3] += 1

    chi2_values = []
    p_values = []

    for i in range(freq_array_pat.shape[0]):
        # Таблица сопряженности для каждой текущей позиции (строки в массиве)
        contingency_table = np.array([freq_array_pat[i], freq_array_ben[i]])
        # Два пропуска, т.к. chi2_contingency возвращает statistic, pvalue, dof и expected_freq
        chi2, p_value, _, _ = chi2_contingency(contingency_table)
        chi2_values.append(chi2)
        p_values.append(p_value)

    return chi2_values, p_values

# %%
chi2_values, p_values = calculate_chi2_p_values(filtered_context_ben_1, filtered_context_pat_1)
counter = 0
for i, (chi2, p_value) in enumerate(zip(chi2_values, p_values)):
    print(f"Position {i}: Chi-square = {chi2}, p-value = {p_value}")
    counter += 1
    if counter == 5:
        print("==="*25)
    if counter == 6:
        print("==="*25)
# Out:
# Position 0: Chi-square = 3.045604362585412, p-value = 0.3846471866467127
# Position 1: Chi-square = 0.218737723194122, p-value = 0.9745091665182819
# Position 2: Chi-square = 1.705990271924223, p-value = 0.6356028432410616
# Position 3: Chi-square = 27.089875101125216, p-value = 5.63738283375677e-06
# Position 4: Chi-square = 114.07624724282448, p-value = 1.4553033944291436e-24
# ===========================================================================
# Position 5: Chi-square = 227.14582162001886, p-value = 5.7266873578642745e-49
# ===========================================================================
# Position 6: Chi-square = 131.0696120401036, p-value = 3.1809935863306594e-28
# Position 7: Chi-square = 9.851534952094429, p-value = 0.01987122985276545
# Position 8: Chi-square = 0.5960842913344759, p-value = 0.8973281975102495
# Position 9: Chi-square = 9.49502630749965, p-value = 0.023384331075560004
# Position 10: Chi-square = 8.239381532092297, p-value = 0.04131499908342435
# Position 11: Chi-square = 1.2061975352287533, p-value = 0.7515182737156034

# %%
chi2_values, p_values = calculate_chi2_p_values(filtered_context_ben_2, filtered_context_pat_2)
counter = 0
for i, (chi2, p_value) in enumerate(zip(chi2_values, p_values)):
    print(f"Position {i}: Chi-square = {chi2}, p-value = {p_value}")
    counter += 1
    if counter == 6:
        print("==="*25)
    if counter == 7:
        print("==="*25)
# Out:
# Position 0: Chi-square = 10.996453954191276, p-value = 0.011745065851252097
# Position 1: Chi-square = 0.7760228565797569, p-value = 0.8551930297627681
# Position 2: Chi-square = 3.9668764369761544, p-value = 0.2650631618434731
# Position 3: Chi-square = 9.241024392415772, p-value = 0.02625218105026831
# Position 4: Chi-square = 38.24121298912729, p-value = 2.5128898449692465e-08
# Position 5: Chi-square = 122.13238057504171, p-value = 2.68015095473661e-26
# ===========================================================================
# Position 6: Chi-square = 226.99560569014912, p-value = 6.171348135219974e-49
# ===========================================================================
# Position 7: Chi-square = 112.38436795760867, p-value = 3.366290965523066e-24
# Position 8: Chi-square = 5.62886113517836, p-value = 0.13113125588185173
# Position 9: Chi-square = 0.7172235336984393, p-value = 0.8691455168534558
# Position 10: Chi-square = 0.6116230326015977, p-value = 0.8937664668444476
# Position 11: Chi-square = 1.3354701430690725, p-value = 0.7207280650367789

# %%
chi2_values, p_values = calculate_chi2_p_values(filtered_context_ben_3, filtered_context_pat_3)
counter = 0
for i, (chi2, p_value) in enumerate(zip(chi2_values, p_values)):
    print(f"Position {i}: Chi-square = {chi2}, p-value = {p_value}")
    counter += 1
    if counter == 7:
        print("==="*25)
    if counter == 8:
        print("==="*25)
# Out:
# Position 0: Chi-square = 0.7188017960483588, p-value = 0.8687729186097658
# Position 1: Chi-square = 2.541234724832359, p-value = 0.46788511416095635
# Position 2: Chi-square = 1.6515884658352435, p-value = 0.6477498618310646
# Position 3: Chi-square = 2.0370036336152264, p-value = 0.5647620924979322
# Position 4: Chi-square = 15.499559438115533, p-value = 0.0014358839689501872
# Position 5: Chi-square = 31.05134485103128, p-value = 8.291483906167602e-07
# Position 6: Chi-square = 112.40689583010128, p-value = 3.328913843709744e-24
# ===========================================================================
# Position 7: Chi-square = 242.47940116351427, p-value = 2.7690107627486857e-52
# ===========================================================================
# Position 8: Chi-square = 121.69258035382228, p-value = 3.333418525517225e-26
# Position 9: Chi-square = 2.1830439620659243, p-value = 0.5352958994702555
# Position 10: Chi-square = 1.3966228694999352, p-value = 0.7063265400419056
# Position 11: Chi-square = 5.165051536230791, p-value = 0.16010260950215963

# %% [markdown]
# Я случайно удалила, как было без pext -_- Степени точно были больше.
