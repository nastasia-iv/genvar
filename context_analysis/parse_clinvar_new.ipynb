# %%
import os

from parse_vcf_clinvar import *

# %%
# parse_clinvar_vcf("/home/tesselle/clinvar/first_1000_lines_anno.vcf.gz")

# %%
parse_clinvar_vcf("data/snp_pat_lpat_clinvar_20250421_anno.vcf.gz")

# %%
import pandas as pd

# %%
df = pd.read_table("data/snp_pat_lpat_clinvar_20250421_anno.vcf.tsv")
# Out:
# /tmp/ipykernel_3176898/861176538.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_table("data/snp_pat_lpat_clinvar_20250421_anno.vcf.tsv")

# %%
df
# Out:
#          CHROM     POS      ID REF ALT  \
# 0         chr1  943995  950448   C   T
# 1         chr1  943995  950448   C   T
# 2         chr1  943995  950448   C   T
# 3         chr1  943995  950448   C   T
# 4         chr1  943995  950448   C   T
# ...        ...     ...     ...  ..  ..
# 2325098  chrMT   16002  690271   T   C
# 2325099  chrMT   16002  690271   T   C
# 2325100  chrMT   16002  690271   T   C
# 2325101  chrMT   16002  690271   T   C
# 2325102  chrMT   16002  690271   T   C
#
#                                                 CLNREVSTAT  \
# 0                      criteria_provided,_single_submitter
# 1                      criteria_provided,_single_submitter
# 2                      criteria_provided,_single_submitter
# 3                      criteria_provided,_single_submitter
# 4                      criteria_provided,_single_submitter
# ...                                                    ...
# 2325098  criteria_provided,_multiple_submitters,_no_con...
# ...

# %%
df['CANONICAL'].value_counts()
# Out:
# CANONICAL
# YES    224079
# Name: count, dtype: int64

# %%
df['Consequence'].value_counts()
# Out:
# Consequence
# stop_gained                                                           327795
# missense_variant                                                      276981
# downstream_gene_variant                                               276204
# upstream_gene_variant                                                 238832
# non_coding_transcript_exon_variant                                    234959
#                                                                        ...
# splice_region_variant&stop_retained_variant&NMD_transcript_variant         7
# stop_lost&splice_region_variant                                            6
# splice_region_variant&stop_retained_variant                                3
# stop_retained_variant                                                      3
# intergenic_variant                                                         2
# Name: count, Length: 65, dtype: int64

# %%
df["MC"].value_counts()
# Out:
# MC
# SO:0001587|nonsense                                                                                                                                                          640235
# SO:0001583|missense_variant                                                                                                                                                  518192
# SO:0001575|splice_donor_variant                                                                                                                                              250644
# SO:0001574|splice_acceptor_variant                                                                                                                                           208988
# SO:0001587|nonsense,SO:0001619|non-coding_transcript_variant                                                                                                                 127216
# ...

# %%
filtered_df = df[(df['CANONICAL'] == 'YES') & df['Consequence'].str.contains('stop_gained', na=False)]

# %%
filtered_df['Consequence'].value_counts()
# Out:
# Consequence
# stop_gained                          57206
# stop_gained&splice_region_variant     2315
# Name: count, dtype: int64

# %%
a = filtered_df[(filtered_df['Consequence'] == 'stop_gained&splice_region_variant')]

# %%
a
# Out:
#         CHROM        POS       ID REF ALT             CLNSIG  \
# 80       chr1    1044111  1076092   G   T         Pathogenic
# 1428     chr1    1825399  1433729   G   A         Pathogenic
# 2007     chr1    2408452  2677658   G   C  Likely_pathogenic
# 2882     chr1    5880114  1455063   G   A         Pathogenic
# 3065     chr1    5967299   968316   G   A         Pathogenic
# ...       ...        ...      ...  ..  ..                ...
# 2303883  chrX  154413567   638931   G   T         Pathogenic
# 2304265  chrX  154419745   202093   G   A         Pathogenic
# 2304303  chrX  154419746   559336   G   T         Pathogenic
# 2304569  chrX  154420262   662186   C   T         Pathogenic
# 2310243  chrX  154561782   426975   C   T         Pathogenic
#
#                              CLNVC       GENEINFO  \
# 80       single_nucleotide_variant    AGRN:375790
# 1428     single_nucleotide_variant      GNB1:2782
# 2007     single_nucleotide_variant     PEX10:5192
# ...

# %%
a["MC"].value_counts()
# Out:
# MC
# SO:0001587|nonsense                                                                                                                                  1724
# SO:0001587|nonsense,SO:0001619|non-coding_transcript_variant                                                                                          238
# SO:0001587|nonsense,SO:0001627|intron_variant                                                                                                         127
# SO:0001587|nonsense,SO:0001623|5_prime_UTR_variant                                                                                                     60
# SO:0001587|nonsense,SO:0001619|non-coding_transcript_variant,SO:0001627|intron_variant                                                                 37
# SO:0001587|nonsense,SO:0001619|non-coding_transcript_variant,SO:0001623|5_prime_UTR_variant                                                            33
# ...

# %%
filtered_df["CLNSIG"].value_counts()
# Out:
# CLNSIG
# Pathogenic                       40183
# Likely_pathogenic                11816
# Pathogenic/Likely_pathogenic      7518
# Pathogenic|other                     2
# Pathogenic|risk_factor               1
# Likely_pathogenic|risk_factor        1
# Name: count, dtype: int64

# %%
filtered_df["CLNVC"].value_counts()
# Out:
# CLNVC
# single_nucleotide_variant    59521
# Name: count, dtype: int64

# %%
filtered_df["CLNSIG"].value_counts()
# Out:
# CLNSIG
# Pathogenic                       40183
# Likely_pathogenic                11816
# Pathogenic/Likely_pathogenic      7518
# Pathogenic|other                     2
# Pathogenic|risk_factor               1
# Likely_pathogenic|risk_factor        1
# Name: count, dtype: int64
